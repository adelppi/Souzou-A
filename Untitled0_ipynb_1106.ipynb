# %% [markdown]
# <a href="https://colab.research.google.com/github/adelppi/Souzou-A/blob/main/Untitled0_ipynb_1106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
#英単語
import requests
from bs4 import BeautifulSoup
import json

URL = "https://tango.mage8.com/word-list"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

data = [i.text for i in soup.find_all("a")]
data = data[8:-6]

for i in data:
  print(i.split("　"))

# %%
import requests
from bs4 import BeautifulSoup
import json

URL = "https://tango.mage8.com/word-list"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

data = [i.text for i in soup.find_all("a")]
data = data[8:-6]

# 単語のリストを作成
word_list = []

for i in data:
    parts = i.split("　")

    # スペースで分割された単語を日本語と英語に分ける
    if len(parts) == 2:
        japanese_word, english_word = parts
        word_dict = {"japanese":japanese_word, "english":english_word}
        word_list.append(word_dict)

# 単語リストをJSON形式に変換
json_data = json.dumps(word_list, ensure_ascii=False, indent=2)

# JSONデータを表示
print(json_data)

# JSONデータをファイルに保存
with open("eitango.json", "w", encoding="utf-8") as json_file:
    json_file.write(json_data)
# Out:
# [
#   {
#     "japanese": "abandon",
#     "english": "捨てる"
#   },
#   {
#     "japanese": "abdomen",
#     "english": "腹部"
#   },
#   {
#     "japanese": "ability",
#     "english": "能力"
#   },
#   {
#     "japanese": "abolish",
#     "english": "廃止する"
#   },
#   {
#     "japanese": "abolition",
#     "english": "廃止"
#   },
#   {
#     "japanese": "absolute",
#     "english": "絶対の"
#   },
#   {
#     "japanese": "absorb",
#     "english": "吸収する"
#   },
#   {
#     "japanese": "abstract",
#     "english": "抽象的な・取り出す"
#   },
#   {
#     "japanese": "absurd",
#     "english": "不合理な"
#   },
#   {
#     "japanese": "abundant",
#     "english": "豊富な"
#   },
#   {
#     "japanese": "accept",
#     "english": "受け入れる"
#   },
#   {
#     "japanese": "accessory",
#     "english": "付属品・アクセサリー"
#   },
#   {
#     "japanese": "access",
#     "english": "接近・利用・接近する・利用する"
#   },
#   {
#     "japanese": "accompany",
#     "english": "同行する"
#   },
#   {
#     "japanese": "accomplish",
#     "english": "成し遂げる"
#   },
#   {
#     "japanese": "account",
#     "english": "会計・口座・説明する"
#   },
#   {
#     "japanese": "accurate",
#     "english": "正確な・精密な"
#   },
#   {
#     "japanese": "accuse",
#     "english": "告訴する・非難する"
#   },
#   {
#     "japanese": "achieve",
#     "english": "成し遂げる"
#   },
#   {
#     "japanese": "acquaintance",
#     "english": "知人"
#   },
#   {
#     "japanese": "acquire",
#     "english": "得る・身につける"
#   },
#   {
#     "japanese": "activate",
#     "english": "活動的にする・作動させる"
#   },
#   {
#     "japanese": "activation",
#     "english": "活性化・アクティベーション"
#   },
#   {
#     "japanese": "active",
#     "english": "活動的な"
#   },
#   {
#     "japanese": "actual",
#     "english": "実際の・現実の"
#   },
#   {
#     "japanese": "adapt",
#     "english": "適合させる"
#   },
#   {
#     "japanese": "additional",
#     "english": "付加的な・追加の"
#   },
#   {
#     "japanese": "addition",
#     "english": "付加・足し算"
#   },
#   {
#     "japanese": "add",
#     "english": "加える"
#   },
#   {
#     "japanese": "adjustment",
#     "english": "調整・調節"
#   },
#   {
#     "japanese": "adjust",
#     "english": "調節する"
#   },
#   {
#     "japanese": "administer",
#     "english": "管理する・統治する・投薬する"
#   },
#   {
#     "japanese": "administration",
#     "english": "管理・運営・行政・投薬"
#   },
#   {
#     "japanese": "administrator",
#     "english": "管理者"
#   },
#   {
#     "japanese": "admire",
#     "english": "感心する"
#   },
#   {
#     "japanese": "adolescence",
#     "english": "青年期"
#   },
#   {
#     "japanese": "adopt",
#     "english": "採用する"
#   },
#   {
#     "japanese": "adorable",
#     "english": "崇拝すべき、かわいらしい"
#   },
#   {
#     "japanese": "adult",
#     "english": "大人・大人の"
#   },
#   {
#     "japanese": "advance",
#     "english": "進める"
#   },
#   {
#     "japanese": "adverse",
#     "english": "逆らう・反対の"
#   },
#   {
#     "japanese": "adversity",
#     "english": "逆境"
#   },
#   {
#     "japanese": "advice",
#     "english": "忠告・助言・通知"
#   },
#   {
#     "japanese": "advise",
#     "english": "忠告する"
#   },
#   {
#     "japanese": "affection",
#     "english": "愛情"
#   },
#   {
#     "japanese": "afford",
#     "english": "～する余裕がある"
#   },
#   {
#     "japanese": "afraid",
#     "english": "恐れて"
#   },
#   {
#     "japanese": "agree",
#     "english": "同意する"
#   },
#   {
#     "japanese": "agriculture",
#     "english": "農業"
#   },
#   {
#     "japanese": "aid",
#     "english": "助ける"
#   },
#   {
#     "japanese": "ailment",
#     "english": "病気・体調不良"
#   },
#   {
#     "japanese": "aim",
#     "english": "狙う"
#   },
#   {
#     "japanese": "allow",
#     "english": "許す"
#   },
#   {
#     "japanese": "alloy",
#     "english": "合金・合金を作る"
#   },
#   {
#     "japanese": "alternate",
#     "english": "交互の"
#   },
#   {
#     "japanese": "altitude",
#     "english": "高度"
#   },
#   {
#     "japanese": "amalgamation",
#     "english": "(会社などの)合併、融合"
#   },
#   {
#     "japanese": "amaze",
#     "english": "びっくりさせる・驚き"
#   },
#   {
#     "japanese": "ambition",
#     "english": "野心・大望"
#   },
#   {
#     "japanese": "amenity",
#     "english": "心地よさ"
#   },
#   {
#     "japanese": "amiable",
#     "english": "愛想の良い"
#   },
#   {
#     "japanese": "amount",
#     "english": "総計"
#   },
#   {
#     "japanese": "analysis",
#     "english": "分析"
#   },
#   {
#     "japanese": "ancestor",
#     "english": "祖先"
#   },
#   {
#     "japanese": "ancient",
#     "english": "古代の"
#   },
#   {
#     "japanese": "anger",
#     "english": "怒り"
#   },
#   {
#     "japanese": "annoy",
#     "english": "いらだたせる"
#   },
#   {
#     "japanese": "annual",
#     "english": "1年の、年1回の"
#   },
#   {
#     "japanese": "annuity",
#     "english": "年金"
#   },
#   {
#     "japanese": "anonymous",
#     "english": "匿名の"
#   },
#   {
#     "japanese": "anticlimax",
#     "english": "あっけない結末"
#   },
#   {
#     "japanese": "anxious",
#     "english": "心配して"
#   },
#   {
#     "japanese": "apparent",
#     "english": "明白な・外見上の"
#   },
#   {
#     "japanese": "appear",
#     "english": "現れる"
#   },
#   {
#     "japanese": "appetite",
#     "english": "食欲・欲望"
#   },
#   {
#     "japanese": "applicant",
#     "english": "応募者・志願者"
#   },
#   {
#     "japanese": "apply",
#     "english": "適用する・申し込む"
#   },
#   {
#     "japanese": "appointment",
#     "english": "任命・約束・予約"
#   },
#   {
#     "japanese": "appoint",
#     "english": "任命する"
#   },
#   {
#     "japanese": "appreciate",
#     "english": "評価する"
#   },
#   {
#     "japanese": "approval",
#     "english": "賛成・承認"
#   },
#   {
#     "japanese": "approve",
#     "english": "良いと認める・賛成する"
#   },
#   {
#     "japanese": "approximately",
#     "english": "おおよそ・ほぼ"
#   },
#   {
#     "japanese": "approximate",
#     "english": "おおよその・近い"
#   },
#   {
#     "japanese": "archaic",
#     "english": "古風な"
#   },
#   {
#     "japanese": "architecture",
#     "english": "建築術"
#   },
#   {
#     "japanese": "area",
#     "english": "面積・地域"
#   },
#   {
#     "japanese": "argue",
#     "english": "議論する"
#   },
#   {
#     "japanese": "argument",
#     "english": "議論・口論・論拠"
#   },
#   {
#     "japanese": "arise",
#     "english": "起こる"
#   },
#   {
#     "japanese": "arm",
#     "english": "腕・武器"
#   },
#   {
#     "japanese": "arrogant",
#     "english": "横柄な・傲慢な"
#   },
#   {
#     "japanese": "article",
#     "english": "記事・条項"
#   },
#   {
#     "japanese": "artificial",
#     "english": "人工の"
#   },
#   {
#     "japanese": "ashamed",
#     "english": "恥じて"
#   },
#   {
#     "japanese": "aspect",
#     "english": "面・様相"
#   },
#   {
#     "japanese": "assault",
#     "english": "急襲・襲う"
#   },
#   {
#     "japanese": "associate",
#     "english": "交際する"
#   },
#   {
#     "japanese": "assume",
#     "english": "～であると仮定する"
#   },
#   {
#     "japanese": "assurance",
#     "english": "保証・確信"
#   },
#   {
#     "japanese": "assure",
#     "english": "保証する"
#   },
#   {
#     "japanese": "astonish",
#     "english": "驚かす"
#   },
#   {
#     "japanese": "astound",
#     "english": "仰天させる"
#   },
#   {
#     "japanese": "astronomy",
#     "english": "天文学"
#   },
#   {
#     "japanese": "atmosphere",
#     "english": "大気"
#   },
#   {
#     "japanese": "attack",
#     "english": "攻撃する・攻撃"
#   },
#   {
#     "japanese": "attain",
#     "english": "達成する・到達する"
#   },
#   {
#     "japanese": "attempt",
#     "english": "試みる・試み"
#   },
#   {
#     "japanese": "attend",
#     "english": "出席する"
#   },
#   {
#     "japanese": "attorney",
#     "english": "法定代理人・弁護士"
#   },
#   {
#     "japanese": "audience",
#     "english": "聴衆"
#   },
#   {
#     "japanese": "authenticity",
#     "english": "確実性"
#   },
#   {
#     "japanese": "authentic",
#     "english": "真正の・本物の"
#   },
#   {
#     "japanese": "authority",
#     "english": "権威"
#   },
#   {
#     "japanese": "author",
#     "english": "著者"
#   },
#   {
#     "japanese": "autocrat",
#     "english": "専制君主"
#   },
#   {
#     "japanese": "available",
#     "english": "利用できる"
#   },
#   {
#     "japanese": "avarice",
#     "english": "強欲"
#   },
#   {
#     "japanese": "avenge",
#     "english": "報復する"
#   },
#   {
#     "japanese": "average",
#     "english": "平均の"
#   },
#   {
#     "japanese": "avoid",
#     "english": "避ける"
#   },
#   {
#     "japanese": "awake",
#     "english": "起こす"
#   },
#   {
#     "japanese": "award",
#     "english": "授与する"
#   },
#   {
#     "japanese": "aware",
#     "english": "気づいて・知って"
#   },
#   {
#     "japanese": "baby",
#     "english": "赤ん坊"
#   },
#   {
#     "japanese": "baggage",
#     "english": "手荷物"
#   },
#   {
#     "japanese": "bandage",
#     "english": "包帯・包帯をする"
#   },
#   {
#     "japanese": "barely",
#     "english": "かろうじて"
#   },
#   {
#     "japanese": "bare",
#     "english": "裸の"
#   },
#   {
#     "japanese": "basic",
#     "english": "基礎の・基礎"
#   },
#   {
#     "japanese": "beam",
#     "english": "光線・梁"
#   },
#   {
#     "japanese": "beard",
#     "english": "ひげ・あごひげ"
#   },
#   {
#     "japanese": "beat",
#     "english": "叩く・(相手を)負かす"
#   },
#   {
#     "japanese": "behave",
#     "english": "振る舞う"
#   },
#   {
#     "japanese": "belief",
#     "english": "信じること"
#   },
#   {
#     "japanese": "belong",
#     "english": "属する"
#   },
#   {
#     "japanese": "bend",
#     "english": "曲げる"
#   },
#   {
#     "japanese": "beneficial",
#     "english": "有益な"
#   },
#   {
#     "japanese": "benefit",
#     "english": "利益"
#   },
#   {
#     "japanese": "benevolent",
#     "english": "慈悲深い"
#   },
#   {
#     "japanese": "beware",
#     "english": "注意する・用心する"
#   },
#   {
#     "japanese": "bewilder",
#     "english": "当惑させる"
#   },
#   {
#     "japanese": "bias",
#     "english": "偏向・～を偏らせる"
#   },
#   {
#     "japanese": "biography",
#     "english": "伝記"
#   },
#   {
#     "japanese": "boldness",
#     "english": "大胆さ"
#   },
#   {
#     "japanese": "bold",
#     "english": "大胆な"
#   },
#   {
#     "japanese": "bookshelf",
#     "english": "本棚"
#   },
#   {
#     "japanese": "border",
#     "english": "へり・国境"
#   },
#   {
#     "japanese": "borrower",
#     "english": "借り手"
#   },
#   {
#     "japanese": "borrow",
#     "english": "借りる"
#   },
#   {
#     "japanese": "botany",
#     "english": "植物学"
#   },
#   {
#     "japanese": "bother",
#     "english": "悩ます・邪魔する"
#   },
#   {
#     "japanese": "bottom",
#     "english": "底"
#   },
#   {
#     "japanese": "bound",
#     "english": "縛られた・はずむ・境界・～行きで"
#   },
#   {
#     "japanese": "bow",
#     "english": "おじぎする"
#   },
#   {
#     "japanese": "boy",
#     "english": "男の子・少年"
#   },
#   {
#     "japanese": "bravery",
#     "english": "勇敢さ"
#   },
#   {
#     "japanese": "brave",
#     "english": "勇敢な"
#   },
#   {
#     "japanese": "bribery",
#     "english": "贈収賄"
#   },
#   {
#     "japanese": "bribe",
#     "english": "賄賂・贈賄する"
#   },
#   {
#     "japanese": "brief",
#     "english": "手短な"
#   },
#   {
#     "japanese": "bright",
#     "english": "明るい"
#   },
#   {
#     "japanese": "broad",
#     "english": "広い"
#   },
#   {
#     "japanese": "browser",
#     "english": "ブラウザー"
#   },
#   {
#     "japanese": "browse",
#     "english": "(家畜が)草を食べる・ざっと目を通す・見て回る"
#   },
#   {
#     "japanese": "budget",
#     "english": "予算(案)"
#   },
#   {
#     "japanese": "burden",
#     "english": "荷物"
#   },
#   {
#     "japanese": "butter",
#     "english": "バター"
#   },
#   {
#     "japanese": "calamity",
#     "english": "災難"
#   },
#   {
#     "japanese": "calculate",
#     "english": "計算する"
#   },
#   {
#     "japanese": "caller",
#     "english": "電話をかける人"
#   },
#   {
#     "japanese": "camel",
#     "english": "ラクダ・駱駝"
#   },
#   {
#     "japanese": "candle",
#     "english": "蝋燭"
#   },
#   {
#     "japanese": "capability",
#     "english": "能力・性能"
#   },
#   {
#     "japanese": "capable",
#     "english": "有能な"
#   },
#   {
#     "japanese": "capacity",
#     "english": "収容力・容量・能力・資格"
#   },
#   {
#     "japanese": "capital",
#     "english": "主要な・首都"
#   },
#   {
#     "japanese": "careless",
#     "english": "不注意な"
#   },
#   {
#     "japanese": "cargo",
#     "english": "貨物"
#   },
#   {
#     "japanese": "carriage",
#     "english": "馬車・台車"
#   },
#   {
#     "japanese": "cart",
#     "english": "荷車・カート"
#   },
#   {
#     "japanese": "casual",
#     "english": "思いつきの"
#   },
#   {
#     "japanese": "catastrophe",
#     "english": "大惨事"
#   },
#   {
#     "japanese": "cause",
#     "english": "原因・～を引き起こす"
#   },
#   {
#     "japanese": "caution",
#     "english": "用心・警告・警告する"
#   },
#   {
#     "japanese": "cease",
#     "english": "終える・止める"
#   },
#   {
#     "japanese": "celestial",
#     "english": "天の"
#   },
#   {
#     "japanese": "certain",
#     "english": "確かな"
#   },
#   {
#     "japanese": "certificate",
#     "english": "証明書"
#   },
#   {
#     "japanese": "certify",
#     "english": "証明する・認証する"
#   },
#   {
#     "japanese": "charcoal",
#     "english": "木炭"
#   },
#   {
#     "japanese": "charge",
#     "english": "代金を請求する・責任を負わせる・料金・責任"
#   },
#   {
#     "japanese": "chart",
#     "english": "図表・グラフ・海図・カルテ"
#   },
#   {
#     "japanese": "cheap",
#     "english": "安い"
#   },
#   {
#     "japanese": "child",
#     "english": "子供"
#   },
#   {
#     "japanese": "circle",
#     "english": "円・回る"
#   },
#   {
#     "japanese": "circuit",
#     "english": "巡回・回路"
#   },
#   {
#     "japanese": "circular",
#     "english": "円形の・回覧の"
#   },
#   {
#     "japanese": "circulate",
#     "english": "循環する・流布する"
#   },
#   {
#     "japanese": "circulation",
#     "english": "循環"
#   },
#   {
#     "japanese": "circumstance",
#     "english": "状況"
#   },
#   {
#     "japanese": "claim",
#     "english": "要求する"
#   },
#   {
#     "japanese": "client",
#     "english": "依頼人・顧客"
#   },
#   {
#     "japanese": "cloth, clothes",
#     "english": "布・衣服"
#   },
#   {
#     "japanese": "clue",
#     "english": "手がかり"
#   },
#   {
#     "japanese": "cluster",
#     "english": "群れ・一団・群がる"
#   },
#   {
#     "japanese": "coal",
#     "english": "石炭"
#   },
#   {
#     "japanese": "colleague",
#     "english": "同僚"
#   },
#   {
#     "japanese": "collect",
#     "english": "集める"
#   },
#   {
#     "japanese": "comedy",
#     "english": "喜劇"
#   },
#   {
#     "japanese": "comfort",
#     "english": "快適・慰める"
#   },
#   {
#     "japanese": "commerce",
#     "english": "商業"
#   },
#   {
#     "japanese": "commit",
#     "english": "(罪などを)犯す"
#   },
#   {
#     "japanese": "common",
#     "english": "共通の・公共の"
#   },
#   {
#     "japanese": "communicate",
#     "english": "伝達する・通じ合う"
#   },
#   {
#     "japanese": "companion",
#     "english": "仲間・伴侶"
#   },
#   {
#     "japanese": "compare",
#     "english": "比較する"
#   },
#   {
#     "japanese": "comparison",
#     "english": "比較"
#   },
#   {
#     "japanese": "compassion",
#     "english": "同情"
#   },
#   {
#     "japanese": "compel",
#     "english": "強いる・強要する"
#   },
#   {
#     "japanese": "compete",
#     "english": "競争する"
#   },
#   {
#     "japanese": "complain",
#     "english": "不平を言う"
#   },
#   {
#     "japanese": "complete",
#     "english": "完全な・完了する"
#   },
#   {
#     "japanese": "complex",
#     "english": "複雑な"
#   },
#   {
#     "japanese": "component",
#     "english": "構成要素・成分・部品"
#   },
#   {
#     "japanese": "compose",
#     "english": "構成する"
#   },
#   {
#     "japanese": "comprehensive",
#     "english": "包括的な"
#   },
#   {
#     "japanese": "compromise",
#     "english": "妥協する"
#   },
#   {
#     "japanese": "comrade",
#     "english": "僚友・同志"
#   },
#   {
#     "japanese": "conceal",
#     "english": "隠す"
#   },
#   {
#     "japanese": "conceive",
#     "english": "思い描く"
#   },
#   {
#     "japanese": "concentrate",
#     "english": "集中する"
#   },
#   {
#     "japanese": "concern",
#     "english": "関係している"
#   },
#   {
#     "japanese": "conclude",
#     "english": "(言動を)終える・結論を下す"
#   },
#   {
#     "japanese": "conclusion",
#     "english": "終わり・結論"
#   },
#   {
#     "japanese": "conference",
#     "english": "会議・協議"
#   },
#   {
#     "japanese": "confine",
#     "english": "制限する・境界"
#   },
#   {
#     "japanese": "confirmation",
#     "english": "確認・確証"
#   },
#   {
#     "japanese": "confirm",
#     "english": "確認する・確証する"
#   },
#   {
#     "japanese": "conflict",
#     "english": "争い"
#   },
#   {
#     "japanese": "confront",
#     "english": "対面する"
#   },
#   {
#     "japanese": "confuse",
#     "english": "混乱させる"
#   },
#   {
#     "japanese": "conquer",
#     "english": "征服する"
#   },
#   {
#     "japanese": "conscience",
#     "english": "良心"
#   },
#   {
#     "japanese": "consensus",
#     "english": "(意見などの)一致"
#   },
#   {
#     "japanese": "consequence",
#     "english": "結果"
#   },
#   {
#     "japanese": "considerable",
#     "english": "考慮すべき・(数量が)かなりの"
#   },
#   {
#     "japanese": "constitute",
#     "english": "構成する"
#   },
#   {
#     "japanese": "construction",
#     "english": "建造"
#   },
#   {
#     "japanese": "constructive",
#     "english": "建設的な"
#   },
#   {
#     "japanese": "construct",
#     "english": "建設する・組み立てる"
#   },
#   {
#     "japanese": "consultant",
#     "english": "相談相手・コンサルタント"
#   },
#   {
#     "japanese": "consult",
#     "english": "(専門家に)意見を聞く・相談する"
#   },
#   {
#     "japanese": "consume",
#     "english": "消費する"
#   },
#   {
#     "japanese": "contemporary",
#     "english": "同時代の"
#   },
#   {
#     "japanese": "continent",
#     "english": "大陸"
#   },
#   {
#     "japanese": "continue",
#     "english": "続ける"
#   },
#   {
#     "japanese": "contrary",
#     "english": "反対の"
#   },
#   {
#     "japanese": "contrast",
#     "english": "対照する・対比する・対照・対比"
#   },
#   {
#     "japanese": "contribute",
#     "english": "寄付する"
#   },
#   {
#     "japanese": "convenient",
#     "english": "便利な"
#   },
#   {
#     "japanese": "conversation",
#     "english": "会話・対話"
#   },
#   {
#     "japanese": "convince",
#     "english": "確信させる"
#   },
#   {
#     "japanese": "cooperate",
#     "english": "協力する"
#   },
#   {
#     "japanese": "core",
#     "english": "(果物の)芯・核心"
#   },
#   {
#     "japanese": "correction",
#     "english": "訂正・修正・補正・矯正"
#   },
#   {
#     "japanese": "correct",
#     "english": "正しい・訂正する"
#   },
#   {
#     "japanese": "correspond",
#     "english": "一致する・文通する"
#   },
#   {
#     "japanese": "courage",
#     "english": "勇気"
#   },
#   {
#     "japanese": "courtesy",
#     "english": "礼儀"
#   },
#   {
#     "japanese": "cousin",
#     "english": "いとこ・従兄弟・従姉妹"
#   },
#   {
#     "japanese": "create",
#     "english": "創造する"
#   },
#   {
#     "japanese": "creep",
#     "english": "這う"
#   },
#   {
#     "japanese": "crime",
#     "english": "犯罪"
#   },
#   {
#     "japanese": "criminal",
#     "english": "犯罪者・犯罪の"
#   },
#   {
#     "japanese": "crisis",
#     "english": "危機"
#   },
#   {
#     "japanese": "criticism",
#     "english": "批判"
#   },
#   {
#     "japanese": "cruel",
#     "english": "残酷な・無慈悲な"
#   },
#   {
#     "japanese": "crunch",
#     "english": "ばりばりと食べる"
#   },
#   {
#     "japanese": "crust",
#     "english": "外皮・パンの耳"
#   },
#   {
#     "japanese": "cultivate",
#     "english": "耕作する"
#   },
#   {
#     "japanese": "cultural",
#     "english": "文化の"
#   },
#   {
#     "japanese": "cure",
#     "english": "治療する"
#   },
#   {
#     "japanese": "curious",
#     "english": "好奇心の強い"
#   },
#   {
#     "japanese": "customer",
#     "english": "顧客・お客"
#   },
#   {
#     "japanese": "custom",
#     "english": "慣習"
#   },
#   {
#     "japanese": "daily",
#     "english": "毎日の・日常の"
#   },
#   {
#     "japanese": "danger",
#     "english": "危険"
#   },
#   {
#     "japanese": "dawn",
#     "english": "夜明け"
#   },
#   {
#     "japanese": "daybreak",
#     "english": "夜明け"
#   },
#   {
#     "japanese": "debate",
#     "english": "討論する"
#   },
#   {
#     "japanese": "decadence",
#     "english": "衰退、退廃"
#   },
#   {
#     "japanese": "decade",
#     "english": "10年間"
#   },
#   {
#     "japanese": "deceive",
#     "english": "騙す"
#   },
#   {
#     "japanese": "decide",
#     "english": "決める"
#   },
#   {
#     "japanese": "decipher",
#     "english": "解読する"
#   },
#   {
#     "japanese": "decision",
#     "english": "決定・決断・決意・判決"
#   },
#   {
#     "japanese": "decisive",
#     "english": "決定的な・決断力のある"
#   },
#   {
#     "japanese": "declare",
#     "english": "宣言する"
#   },
#   {
#     "japanese": "decline",
#     "english": "辞退する"
#   },
#   {
#     "japanese": "decrease",
#     "english": "減る"
#   },
#   {
#     "japanese": "deed",
#     "english": "行い・捺印証書"
#   },
#   {
#     "japanese": "defeat",
#     "english": "(相手を)負かす・敗北"
#   },
#   {
#     "japanese": "defect",
#     "english": "欠点"
#   },
#   {
#     "japanese": "defendant",
#     "english": "被告・被告の"
#   },
#   {
#     "japanese": "defend",
#     "english": "守る"
#   },
#   {
#     "japanese": "define",
#     "english": "定義する"
#   },
#   {
#     "japanese": "deflate",
#     "english": "しぼませる"
#   },
#   {
#     "japanese": "deflation",
#     "english": "デフレーション・収縮"
#   },
#   {
#     "japanese": "degree",
#     "english": "程度"
#   },
#   {
#     "japanese": "delay",
#     "english": "遅らせる"
#   },
#   {
#     "japanese": "delegate",
#     "english": "代表者"
#   },
#   {
#     "japanese": "delight",
#     "english": "喜び・喜ばす"
#   },
#   {
#     "japanese": "deliver",
#     "english": "配達する"
#   },
#   {
#     "japanese": "demand",
#     "english": "要求する・要求"
#   },
#   {
#     "japanese": "dense",
#     "english": "濃密な"
#   },
#   {
#     "japanese": "density",
#     "english": "密度・濃度"
#   },
#   {
#     "japanese": "deny",
#     "english": "否定する"
#   },
#   {
#     "japanese": "department",
#     "english": "部門・部局"
#   },
#   {
#     "japanese": "depart",
#     "english": "出発する・逸脱する"
#   },
#   {
#     "japanese": "depend",
#     "english": "頼る"
#   },
#   {
#     "japanese": "depressed",
#     "english": "落ち込んで"
#   },
#   {
#     "japanese": "depression",
#     "english": "意気消沈・不景気"
#   },
#   {
#     "japanese": "depress",
#     "english": "落ち込ませる・押し下げる"
#   },
#   {
#     "japanese": "depth",
#     "english": "深さ"
#   },
#   {
#     "japanese": "derive",
#     "english": "引き出す・由来する"
#   },
#   {
#     "japanese": "descendant",
#     "english": "子孫"
#   },
#   {
#     "japanese": "describe",
#     "english": "記述する"
#   },
#   {
#     "japanese": "description",
#     "english": "記述・説明"
#   },
#   {
#     "japanese": "desire",
#     "english": "欲望・欲する"
#   },
#   {
#     "japanese": "despair",
#     "english": "絶望"
#   },
#   {
#     "japanese": "despise",
#     "english": "軽蔑する"
#   },
#   {
#     "japanese": "despot",
#     "english": "専制君主"
#   },
#   {
#     "japanese": "destiny",
#     "english": "運命"
#   },
#   {
#     "japanese": "destroy",
#     "english": "破壊する"
#   },
#   {
#     "japanese": "destruction",
#     "english": "破壊"
#   },
#   {
#     "japanese": "destructive",
#     "english": "破壊的な"
#   },
#   {
#     "japanese": "detail",
#     "english": "細部"
#   },
#   {
#     "japanese": "detergent",
#     "english": "洗剤"
#   },
#   {
#     "japanese": "determine",
#     "english": "決定する・決心する"
#   },
#   {
#     "japanese": "deter",
#     "english": "抑止する"
#   },
#   {
#     "japanese": "develop",
#     "english": "発達させる"
#   },
#   {
#     "japanese": "device",
#     "english": "装置"
#   },
#   {
#     "japanese": "devote",
#     "english": "(心身を)捧げる"
#   },
#   {
#     "japanese": "diagram",
#     "english": "図・図形"
#   },
#   {
#     "japanese": "dialect",
#     "english": "方言"
#   },
#   {
#     "japanese": "dictator",
#     "english": "独裁者"
#   },
#   {
#     "japanese": "different",
#     "english": "違う"
#   },
#   {
#     "japanese": "differ",
#     "english": "違う"
#   },
#   {
#     "japanese": "dignity",
#     "english": "威厳"
#   },
#   {
#     "japanese": "diligent",
#     "english": "勤勉な"
#   },
#   {
#     "japanese": "diminish",
#     "english": "減らす"
#   },
#   {
#     "japanese": "diplomacy",
#     "english": "外交"
#   },
#   {
#     "japanese": "diplomatic",
#     "english": "外交上の"
#   },
#   {
#     "japanese": "disappointment",
#     "english": "失望"
#   },
#   {
#     "japanese": "disappoint",
#     "english": "失望させる"
#   },
#   {
#     "japanese": "disaster",
#     "english": "災害"
#   },
#   {
#     "japanese": "discipline",
#     "english": "訓練"
#   },
#   {
#     "japanese": "discourage",
#     "english": "失望させる"
#   },
#   {
#     "japanese": "disease",
#     "english": "病気・疾患"
#   },
#   {
#     "japanese": "dismiss",
#     "english": "解散させる・退ける"
#   },
#   {
#     "japanese": "display",
#     "english": "陳列する"
#   },
#   {
#     "japanese": "dispute",
#     "english": "論争、論じる"
#   },
#   {
#     "japanese": "dissuade",
#     "english": "思いとどまらせる"
#   },
#   {
#     "japanese": "distant",
#     "english": "遠い・離れた"
#   },
#   {
#     "japanese": "distinguish",
#     "english": "区別する"
#   },
#   {
#     "japanese": "distribution",
#     "english": "分配"
#   },
#   {
#     "japanese": "district",
#     "english": "地区"
#   },
#   {
#     "japanese": "disturb",
#     "english": "乱す・邪魔をする"
#   },
#   {
#     "japanese": "divide",
#     "english": "分ける"
#   },
#   {
#     "japanese": "division",
#     "english": "分割、区分"
#   },
#   {
#     "japanese": "documentary",
#     "english": "文書の・ドキュメンタリー"
#   },
#   {
#     "japanese": "document",
#     "english": "文書・書類"
#   },
#   {
#     "japanese": "domestic",
#     "english": "家庭の"
#   },
#   {
#     "japanese": "doom",
#     "english": "悲運"
#   },
#   {
#     "japanese": "doubt",
#     "english": "疑う・疑い"
#   },
#   {
#     "japanese": "dramatic",
#     "english": "劇の・劇的な"
#   },
#   {
#     "japanese": "drama",
#     "english": "劇・ドラマ"
#   },
#   {
#     "japanese": "drill",
#     "english": "ドリル・訓練・穴をあける"
#   },
#   {
#     "japanese": "driver",
#     "english": "運転手"
#   },
#   {
#     "japanese": "drought",
#     "english": "干ばつ・渇水"
#   },
#   {
#     "japanese": "due",
#     "english": "支払期限の来た"
#   },
#   {
#     "japanese": "dull",
#     "english": "鈍い"
#   },
#   {
#     "japanese": "duplicate",
#     "english": "複製する"
#   },
#   {
#     "japanese": "durability",
#     "english": "耐久性・永続性"
#   },
#   {
#     "japanese": "durable",
#     "english": "耐久性のある・永続的な"
#   },
#   {
#     "japanese": "dusk",
#     "english": "夕闇"
#   },
#   {
#     "japanese": "duty",
#     "english": "義務"
#   },
#   {
#     "japanese": "eager",
#     "english": "熱心な"
#   },
#   {
#     "japanese": "earn",
#     "english": "稼ぐ"
#   },
#   {
#     "japanese": "earthly",
#     "english": "地球の・地上の"
#   },
#   {
#     "japanese": "ease",
#     "english": "安楽・楽にする"
#   },
#   {
#     "japanese": "easily",
#     "english": "容易に"
#   },
#   {
#     "japanese": "eatable",
#     "english": "食べられる"
#   },
#   {
#     "japanese": "eavesdrop",
#     "english": "立ち聞きする"
#   },
#   {
#     "japanese": "echo",
#     "english": "こだま・(音が)反響する"
#   },
#   {
#     "japanese": "eclipse",
#     "english": "日食・月食"
#   },
#   {
#     "japanese": "economy",
#     "english": "節約・経済"
#   },
#   {
#     "japanese": "ecstasy",
#     "english": "恍惚"
#   },
#   {
#     "japanese": "edible",
#     "english": "食べられる・食用の"
#   },
#   {
#     "japanese": "editor",
#     "english": "編集者"
#   },
#   {
#     "japanese": "educate",
#     "english": "教育する"
#   },
#   {
#     "japanese": "education",
#     "english": "教育"
#   },
#   {
#     "japanese": "effect",
#     "english": "結果・効果"
#   },
#   {
#     "japanese": "elder",
#     "english": "年上の・年長者"
#   },
#   {
#     "japanese": "election",
#     "english": "選挙"
#   },
#   {
#     "japanese": "electricity",
#     "english": "電気"
#   },
#   {
#     "japanese": "elegant",
#     "english": "上品な・優雅な"
#   },
#   {
#     "japanese": "elevation",
#     "english": "高めること"
#   },
#   {
#     "japanese": "eliminate",
#     "english": "除去する"
#   },
#   {
#     "japanese": "eloquent",
#     "english": "雄弁な"
#   },
#   {
#     "japanese": "embrace",
#     "english": "抱き締める・受け入れる"
#   },
#   {
#     "japanese": "emergency",
#     "english": "非常時・緊急事態"
#   },
#   {
#     "japanese": "emir",
#     "english": "(イスラム教国の)首長"
#   },
#   {
#     "japanese": "emotion",
#     "english": "感情"
#   },
#   {
#     "japanese": "emphasis",
#     "english": "強調"
#   },
#   {
#     "japanese": "empty",
#     "english": "空の・空にする"
#   },
#   {
#     "japanese": "enable",
#     "english": "可能にさせる"
#   },
#   {
#     "japanese": "enclose",
#     "english": "同封する・取り囲む"
#   },
#   {
#     "japanese": "endanger",
#     "english": "危険にさらす"
#   },
#   {
#     "japanese": "endure",
#     "english": "耐える"
#   },
#   {
#     "japanese": "enemy",
#     "english": "敵・敵の"
#   },
#   {
#     "japanese": "energy",
#     "english": "精力・エネルギー"
#   },
#   {
#     "japanese": "enforce",
#     "english": "(強制的に)実施する・強要する"
#   },
#   {
#     "japanese": "engage",
#     "english": "従事する"
#   },
#   {
#     "japanese": "enhancement",
#     "english": "向上・増進"
#   },
#   {
#     "japanese": "enhance",
#     "english": "(価値や質を)高める"
#   },
#   {
#     "japanese": "enjoyment",
#     "english": "楽しみ"
#   },
#   {
#     "japanese": "enlargement",
#     "english": "拡大・増大"
#   },
#   {
#     "japanese": "enlarge",
#     "english": "大きくする・拡大する"
#   },
#   {
#     "japanese": "enormous",
#     "english": "巨大な"
#   },
#   {
#     "japanese": "enter",
#     "english": "入る・記入する"
#   },
#   {
#     "japanese": "enthusiasm",
#     "english": "熱中・熱意"
#   },
#   {
#     "japanese": "enthusiastic",
#     "english": "熱烈な・熱中して"
#   },
#   {
#     "japanese": "entire",
#     "english": "全体の"
#   },
#   {
#     "japanese": "entrance",
#     "english": "入り口・入ること・うっとりさせる"
#   },
#   {
#     "japanese": "entry",
#     "english": "入ること・入り口・記入"
#   },
#   {
#     "japanese": "envelope",
#     "english": "封筒"
#   },
#   {
#     "japanese": "envelop",
#     "english": "包む"
#   },
#   {
#     "japanese": "environment",
#     "english": "環境"
#   },
#   {
#     "japanese": "envy",
#     "english": "ねたみ・ねたむ"
#   },
#   {
#     "japanese": "epoch",
#     "english": "新紀元"
#   },
#   {
#     "japanese": "equipment",
#     "english": "設備・装備・機器"
#   },
#   {
#     "japanese": "equip",
#     "english": "備える・身につけさせる"
#   },
#   {
#     "japanese": "era",
#     "english": "時代"
#   },
#   {
#     "japanese": "escapade",
#     "english": "脱線行為"
#   },
#   {
#     "japanese": "establish",
#     "english": "設立する"
#   },
#   {
#     "japanese": "estimate",
#     "english": "見積もる"
#   },
#   {
#     "japanese": "evidence",
#     "english": "証拠"
#   },
#   {
#     "japanese": "evident",
#     "english": "明白な・明らかな"
#   },
#   {
#     "japanese": "evil",
#     "english": "悪い・悪"
#   },
#   {
#     "japanese": "evolve",
#     "english": "展開する・進化する"
#   },
#   {
#     "japanese": "exact",
#     "english": "正確な"
#   },
#   {
#     "japanese": "examine",
#     "english": "調査する"
#   },
#   {
#     "japanese": "example",
#     "english": "例・実例"
#   },
#   {
#     "japanese": "exceptional",
#     "english": "例外的な・並外れた"
#   },
#   {
#     "japanese": "exception",
#     "english": "例外・除外・異議"
#   },
#   {
#     "japanese": "except",
#     "english": "～を除いて・～でなければ"
#   },
#   {
#     "japanese": "exchange",
#     "english": "交換する"
#   },
#   {
#     "japanese": "excursion",
#     "english": "遠足"
#   },
#   {
#     "japanese": "exhaustion",
#     "english": "消耗・疲労"
#   },
#   {
#     "japanese": "exhaust",
#     "english": "使い尽くす"
#   },
#   {
#     "japanese": "exhibit",
#     "english": "展示する"
#   },
#   {
#     "japanese": "exist",
#     "english": "存在する"
#   },
#   {
#     "japanese": "exit",
#     "english": "出口・退出・出て行く"
#   },
#   {
#     "japanese": "expedient",
#     "english": "好都合な"
#   },
#   {
#     "japanese": "expedition",
#     "english": "遠征"
#   },
#   {
#     "japanese": "expensive",
#     "english": "高価な"
#   },
#   {
#     "japanese": "experience",
#     "english": "経験"
#   },
#   {
#     "japanese": "experiment",
#     "english": "実験・実験する"
#   },
#   {
#     "japanese": "explain",
#     "english": "説明する"
#   },
#   {
#     "japanese": "explanation",
#     "english": "説明"
#   },
#   {
#     "japanese": "explode",
#     "english": "爆発する"
#   },
#   {
#     "japanese": "explore",
#     "english": "探検する"
#   },
#   {
#     "japanese": "export",
#     "english": "輸出する"
#   },
#   {
#     "japanese": "expose",
#     "english": "(日光・風雨に)さらす"
#   },
#   {
#     "japanese": "express",
#     "english": "表現する"
#   },
#   {
#     "japanese": "extend",
#     "english": "伸ばす"
#   },
#   {
#     "japanese": "extent",
#     "english": "広さ、程度"
#   },
#   {
#     "japanese": "exterior",
#     "english": "外部の・外側の"
#   },
#   {
#     "japanese": "external",
#     "english": "外部の"
#   },
#   {
#     "japanese": "extinct",
#     "english": "絶滅した"
#   },
#   {
#     "japanese": "fabulous",
#     "english": "伝説的な、素晴らしい"
#   },
#   {
#     "japanese": "facility",
#     "english": "施設・設備"
#   },
#   {
#     "japanese": "factory",
#     "english": "工場"
#   },
#   {
#     "japanese": "failure",
#     "english": "失敗・不足・故障"
#   },
#   {
#     "japanese": "fail",
#     "english": "失敗する"
#   },
#   {
#     "japanese": "faith",
#     "english": "信頼・信念"
#   },
#   {
#     "japanese": "fake",
#     "english": "偽の"
#   },
#   {
#     "japanese": "familiar",
#     "english": "よく知られている"
#   },
#   {
#     "japanese": "famine",
#     "english": "飢饉"
#   },
#   {
#     "japanese": "fancy",
#     "english": "空想・空想する"
#   },
#   {
#     "japanese": "farce",
#     "english": "笑劇・茶番"
#   },
#   {
#     "japanese": "farewell",
#     "english": "別れ・別れの言葉"
#   },
#   {
#     "japanese": "fare",
#     "english": "運賃"
#   },
#   {
#     "japanese": "fascinate",
#     "english": "魅了する"
#   },
#   {
#     "japanese": "fate",
#     "english": "運命"
#   },
#   {
#     "japanese": "fat",
#     "english": "太った・脂肪"
#   },
#   {
#     "japanese": "favor",
#     "english": "好意"
#   },
#   {
#     "japanese": "feast",
#     "english": "祝宴"
#   },
#   {
#     "japanese": "feature",
#     "english": "特徴"
#   },
#   {
#     "japanese": "feces",
#     "english": "糞便"
#   },
#   {
#     "japanese": "fee",
#     "english": "料金・報酬"
#   },
#   {
#     "japanese": "fellow",
#     "english": "男・(男の)仲間"
#   },
#   {
#     "japanese": "female",
#     "english": "女性"
#   },
#   {
#     "japanese": "fertile",
#     "english": "肥沃な・多産な"
#   },
#   {
#     "japanese": "figure",
#     "english": "形・姿・数字・図で表す・計算する"
#   },
#   {
#     "japanese": "financial",
#     "english": "財政上の"
#   },
#   {
#     "japanese": "fine",
#     "english": "素晴らしい"
#   },
#   {
#     "japanese": "firm",
#     "english": "硬い"
#   },
#   {
#     "japanese": "fit",
#     "english": "適当な・適合する"
#   },
#   {
#     "japanese": "fix",
#     "english": "固定する"
#   },
#   {
#     "japanese": "flash",
#     "english": "ひらめき・ひらめく"
#   },
#   {
#     "japanese": "flatter",
#     "english": "お世辞を言う"
#   },
#   {
#     "japanese": "flavor",
#     "english": "風味・味わい"
#   },
#   {
#     "japanese": "flicker",
#     "english": "揺らめく・揺らめき"
#   },
#   {
#     "japanese": "flood",
#     "english": "洪水"
#   },
#   {
#     "japanese": "fluent",
#     "english": "流暢な"
#   },
#   {
#     "japanese": "fluid",
#     "english": "流体・流動性の"
#   },
#   {
#     "japanese": "foe",
#     "english": "敵"
#   },
#   {
#     "japanese": "foolish",
#     "english": "愚かな"
#   },
#   {
#     "japanese": "force",
#     "english": "力・強要する"
#   },
#   {
#     "japanese": "forecast",
#     "english": "予測する・予測"
#   },
#   {
#     "japanese": "forefather",
#     "english": "先祖"
#   },
#   {
#     "japanese": "forehead",
#     "english": "額・おでこ"
#   },
#   {
#     "japanese": "forgetful",
#     "english": "忘れっぽい"
#   },
#   {
#     "japanese": "forget",
#     "english": "忘れる"
#   },
#   {
#     "japanese": "forgiveness",
#     "english": "許し・許すこと"
#   },
#   {
#     "japanese": "forgive",
#     "english": "許す"
#   },
#   {
#     "japanese": "formal",
#     "english": "正式の・形式ばった"
#   },
#   {
#     "japanese": "former",
#     "english": "前の"
#   },
#   {
#     "japanese": "fortnight",
#     "english": "二週間"
#   },
#   {
#     "japanese": "fortune",
#     "english": "運"
#   },
#   {
#     "japanese": "found",
#     "english": "創設する"
#   },
#   {
#     "japanese": "fragile",
#     "english": "壊れやすい"
#   },
#   {
#     "japanese": "fragrance",
#     "english": "香り"
#   },
#   {
#     "japanese": "freedom",
#     "english": "自由"
#   },
#   {
#     "japanese": "freight",
#     "english": "貨物輸送・運賃・積み荷"
#   },
#   {
#     "japanese": "frequent",
#     "english": "たびたびの"
#   },
#   {
#     "japanese": "freshwater",
#     "english": "淡水・淡水の"
#   },
#   {
#     "japanese": "fresh",
#     "english": "新鮮な"
#   },
#   {
#     "japanese": "friend",
#     "english": "友達"
#   },
#   {
#     "japanese": "frighten",
#     "english": "怖がらせる"
#   },
#   {
#     "japanese": "frigid",
#     "english": "極寒の・冷ややかな"
#   },
#   {
#     "japanese": "fuel",
#     "english": "燃料"
#   },
#   {
#     "japanese": "fulfill",
#     "english": "遂行する"
#   },
#   {
#     "japanese": "function",
#     "english": "機能"
#   },
#   {
#     "japanese": "fundamental",
#     "english": "基本の・基本"
#   },
#   {
#     "japanese": "fun",
#     "english": "楽しみ"
#   },
#   {
#     "japanese": "furnish",
#     "english": "供給する"
#   },
#   {
#     "japanese": "fury",
#     "english": "憤激"
#   },
#   {
#     "japanese": "gadget",
#     "english": "目新しい小道具・ガジェット"
#   },
#   {
#     "japanese": "gain",
#     "english": "得る"
#   },
#   {
#     "japanese": "gasoline",
#     "english": "ガソリン"
#   },
#   {
#     "japanese": "gas",
#     "english": "気体・ガス"
#   },
#   {
#     "japanese": "gather",
#     "english": "集める"
#   },
#   {
#     "japanese": "gaze",
#     "english": "見つめる"
#   },
#   {
#     "japanese": "generous",
#     "english": "気前のよい"
#   },
#   {
#     "japanese": "gene",
#     "english": "遺伝子"
#   },
#   {
#     "japanese": "genuine",
#     "english": "本物の"
#   },
#   {
#     "japanese": "geography",
#     "english": "地理学"
#   },
#   {
#     "japanese": "gesture",
#     "english": "身ぶり・身ぶりで示す"
#   },
#   {
#     "japanese": "girl",
#     "english": "女の子・少女"
#   },
#   {
#     "japanese": "glance",
#     "english": "ちらりと見る"
#   },
#   {
#     "japanese": "glare",
#     "english": "まぶしい光"
#   },
#   {
#     "japanese": "gleam",
#     "english": "かすかな光"
#   },
#   {
#     "japanese": "glimmer",
#     "english": "かすかな光"
#   },
#   {
#     "japanese": "glint",
#     "english": "きらっと光る"
#   },
#   {
#     "japanese": "glisten",
#     "english": "きらきら輝く"
#   },
#   {
#     "japanese": "glitter",
#     "english": "ぴかぴか光る"
#   },
#   {
#     "japanese": "global",
#     "english": "全世界の・地球の"
#   },
#   {
#     "japanese": "globe",
#     "english": "球・地球"
#   },
#   {
#     "japanese": "glow",
#     "english": "白熱光"
#   },
#   {
#     "japanese": "govern",
#     "english": "統治する"
#   },
#   {
#     "japanese": "graduate",
#     "english": "卒業する"
#   },
#   {
#     "japanese": "grain",
#     "english": "穀物"
#   },
#   {
#     "japanese": "grateful",
#     "english": "感謝している"
#   },
#   {
#     "japanese": "grate",
#     "english": "すりおろす・火格子"
#   },
#   {
#     "japanese": "gravitation",
#     "english": "引力・重力"
#   },
#   {
#     "japanese": "greed",
#     "english": "貪欲"
#   },
#   {
#     "japanese": "greet",
#     "english": "あいさつする"
#   },
#   {
#     "japanese": "grief",
#     "english": "悲嘆"
#   },
#   {
#     "japanese": "grocery",
#     "english": "食料雑貨店"
#   },
#   {
#     "japanese": "guarantee",
#     "english": "保証・保証する"
#   },
#   {
#     "japanese": "guaranty",
#     "english": "保証"
#   },
#   {
#     "japanese": "guardian",
#     "english": "保護者・守護者・後見人"
#   },
#   {
#     "japanese": "guard",
#     "english": "守る・見張る・護衛・見張り"
#   },
#   {
#     "japanese": "guess",
#     "english": "推測する"
#   },
#   {
#     "japanese": "guest",
#     "english": "招待客"
#   },
#   {
#     "japanese": "guilty",
#     "english": "有罪の"
#   },
#   {
#     "japanese": "gulp",
#     "english": "ごくごく飲む・がつがつ食べる"
#   },
#   {
#     "japanese": "habit",
#     "english": "習慣"
#   },
#   {
#     "japanese": "hardly",
#     "english": "ほとんど～ない"
#   },
#   {
#     "japanese": "harm",
#     "english": "害する"
#   },
#   {
#     "japanese": "harsh",
#     "english": "厳しい・不快な"
#   },
#   {
#     "japanese": "harvest",
#     "english": "収穫"
#   },
#   {
#     "japanese": "hate",
#     "english": "憎む"
#   },
#   {
#     "japanese": "hazard",
#     "english": "危険"
#   },
#   {
#     "japanese": "headquarters",
#     "english": "本部・本社"
#   },
#   {
#     "japanese": "hearing",
#     "english": "聴覚"
#   },
#   {
#     "japanese": "heaven",
#     "english": "天国"
#   },
#   {
#     "japanese": "height",
#     "english": "高さ"
#   },
#   {
#     "japanese": "hell",
#     "english": "地獄"
#   },
#   {
#     "japanese": "hesitate",
#     "english": "躊躇する"
#   },
#   {
#     "japanese": "hierarchy",
#     "english": "階層・階層制度"
#   },
#   {
#     "japanese": "hinder",
#     "english": "妨げる"
#   },
#   {
#     "japanese": "horizontal",
#     "english": "水平な"
#   },
#   {
#     "japanese": "horizon",
#     "english": "地平線"
#   },
#   {
#     "japanese": "horrible",
#     "english": "恐ろしい・ひどい"
#   },
#   {
#     "japanese": "horrific",
#     "english": "恐ろしい・身の毛もよだつ"
#   },
#   {
#     "japanese": "hostile",
#     "english": "敵の・敵意のある"
#   },
#   {
#     "japanese": "huge",
#     "english": "巨大な"
#   },
#   {
#     "japanese": "humble",
#     "english": "謙虚な"
#   },
#   {
#     "japanese": "hungry",
#     "english": "飢えた・腹の減った"
#   },
#   {
#     "japanese": "hurt",
#     "english": "怪我をさせる"
#   },
#   {
#     "japanese": "hydrogen",
#     "english": "水素"
#   },
#   {
#     "japanese": "ideal",
#     "english": "理想・理想的な"
#   },
#   {
#     "japanese": "identify",
#     "english": "見分ける"
#   },
#   {
#     "japanese": "ignorance",
#     "english": "無知"
#   },
#   {
#     "japanese": "ignorant",
#     "english": "無知な"
#   },
#   {
#     "japanese": "ignore",
#     "english": "無視する"
#   },
#   {
#     "japanese": "illness",
#     "english": "病気"
#   },
#   {
#     "japanese": "illuminate",
#     "english": "光を照らす"
#   },
#   {
#     "japanese": "imagine",
#     "english": "想像する"
#   },
#   {
#     "japanese": "imbecile",
#     "english": "低脳な"
#   },
#   {
#     "japanese": "imitate",
#     "english": "模倣する"
#   },
#   {
#     "japanese": "impede",
#     "english": "妨げる"
#   },
#   {
#     "japanese": "imperil",
#     "english": "危険にさらす"
#   },
#   {
#     "japanese": "implement",
#     "english": "道具・実行する"
#   },
#   {
#     "japanese": "importance",
#     "english": "重要性・大切さ"
#   },
#   {
#     "japanese": "important",
#     "english": "重要な・大切な"
#   },
#   {
#     "japanese": "import",
#     "english": "輸入する"
#   },
#   {
#     "japanese": "impress",
#     "english": "印象を与える・感動させる"
#   },
#   {
#     "japanese": "improper",
#     "english": "不適当な"
#   },
#   {
#     "japanese": "impudent",
#     "english": "厚かましい"
#   },
#   {
#     "japanese": "inability",
#     "english": "能力の欠如"
#   },
#   {
#     "japanese": "incentive",
#     "english": "動機・刺激"
#   },
#   {
#     "japanese": "inclement",
#     "english": "(天候が)荒れ模様の"
#   },
#   {
#     "japanese": "include",
#     "english": "含む"
#   },
#   {
#     "japanese": "income",
#     "english": "収入"
#   },
#   {
#     "japanese": "increase",
#     "english": "増える"
#   },
#   {
#     "japanese": "independent",
#     "english": "独立した"
#   },
#   {
#     "japanese": "index",
#     "english": "索引・指針・指数"
#   },
#   {
#     "japanese": "indicate",
#     "english": "指し示す"
#   },
#   {
#     "japanese": "indifferent",
#     "english": "無関心な"
#   },
#   {
#     "japanese": "individual",
#     "english": "個々の"
#   },
#   {
#     "japanese": "industry",
#     "english": "産業"
#   },
#   {
#     "japanese": "infant",
#     "english": "幼児"
#   },
#   {
#     "japanese": "inferior",
#     "english": "下位の"
#   },
#   {
#     "japanese": "infinite",
#     "english": "無限の"
#   },
#   {
#     "japanese": "inflate",
#     "english": "膨らませる"
#   },
#   {
#     "japanese": "inflation",
#     "english": "インフレーション・膨張"
#   },
#   {
#     "japanese": "influence",
#     "english": "影響"
#   },
#   {
#     "japanese": "informal",
#     "english": "非公式の・略式の"
#   },
#   {
#     "japanese": "inform",
#     "english": "知らせる"
#   },
#   {
#     "japanese": "inherit",
#     "english": "相続する"
#   },
#   {
#     "japanese": "inhibit",
#     "english": "抑制する"
#   },
#   {
#     "japanese": "injection",
#     "english": "注入・注射"
#   },
#   {
#     "japanese": "inject",
#     "english": "注入する・注射する"
#   },
#   {
#     "japanese": "injure",
#     "english": "傷つける"
#   },
#   {
#     "japanese": "innovate",
#     "english": "革新する"
#   },
#   {
#     "japanese": "innovation",
#     "english": "革新"
#   },
#   {
#     "japanese": "inquire",
#     "english": "尋ねる・調査する"
#   },
#   {
#     "japanese": "insert",
#     "english": "挿入する"
#   },
#   {
#     "japanese": "inside",
#     "english": "内部・内側の"
#   },
#   {
#     "japanese": "insist",
#     "english": "主張する"
#   },
#   {
#     "japanese": "insoluble",
#     "english": "解決できない"
#   },
#   {
#     "japanese": "inspection",
#     "english": "検査・視察"
#   },
#   {
#     "japanese": "inspect",
#     "english": "検査する・視察する"
#   },
#   {
#     "japanese": "instance",
#     "english": "例・実例"
#   },
#   {
#     "japanese": "instead",
#     "english": "代わりに"
#   },
#   {
#     "japanese": "instinct",
#     "english": "本能"
#   },
#   {
#     "japanese": "instruction",
#     "english": "指示"
#   },
#   {
#     "japanese": "instrument",
#     "english": "器具"
#   },
#   {
#     "japanese": "insult",
#     "english": "侮辱する・侮辱"
#   },
#   {
#     "japanese": "insurance",
#     "english": "保険"
#   },
#   {
#     "japanese": "integrity",
#     "english": "高潔・完全性"
#   },
#   {
#     "japanese": "intellectual",
#     "english": "知的な"
#   },
#   {
#     "japanese": "intelligence",
#     "english": "知能"
#   },
#   {
#     "japanese": "intelligent",
#     "english": "聡明な"
#   },
#   {
#     "japanese": "intense",
#     "english": "激しい"
#   },
#   {
#     "japanese": "interest",
#     "english": "興味・利益"
#   },
#   {
#     "japanese": "interfere",
#     "english": "邪魔をする"
#   },
#   {
#     "japanese": "interior",
#     "english": "内部の・内側の"
#   },
#   {
#     "japanese": "intermission",
#     "english": "休止・中断"
#   },
#   {
#     "japanese": "intermittent",
#     "english": "断続的な"
#   },
#   {
#     "japanese": "internal",
#     "english": "内部の"
#   },
#   {
#     "japanese": "interpose",
#     "english": "間に置く・間に割って入る"
#   },
#   {
#     "japanese": "interpret",
#     "english": "解釈する・通訳する"
#   },
#   {
#     "japanese": "interval",
#     "english": "間隔"
#   },
#   {
#     "japanese": "introduce",
#     "english": "紹介する"
#   },
#   {
#     "japanese": "introspective",
#     "english": "内省的な"
#   },
#   {
#     "japanese": "intuition",
#     "english": "直感"
#   },
#   {
#     "japanese": "invalidate",
#     "english": "無効にする"
#   },
#   {
#     "japanese": "invalid",
#     "english": "無効な・病弱な"
#   },
#   {
#     "japanese": "invent",
#     "english": "発明する"
#   },
#   {
#     "japanese": "investigate",
#     "english": "調査する"
#   },
#   {
#     "japanese": "investigation",
#     "english": "調査・研究・捜査"
#   },
#   {
#     "japanese": "investor",
#     "english": "投資家"
#   },
#   {
#     "japanese": "invite",
#     "english": "招待する"
#   },
#   {
#     "japanese": "involve",
#     "english": "巻き込む"
#   },
#   {
#     "japanese": "iron",
#     "english": "鉄・鉄製の・アイロンをかける"
#   },
#   {
#     "japanese": "isolated",
#     "english": "孤立した・隔離された"
#   },
#   {
#     "japanese": "isolate",
#     "english": "孤立させる"
#   },
#   {
#     "japanese": "isolation",
#     "english": "分離・孤立"
#   },
#   {
#     "japanese": "issue",
#     "english": "発行・出版する"
#   },
#   {
#     "japanese": "jackpot",
#     "english": "大当たり"
#   },
#   {
#     "japanese": "jealous",
#     "english": "嫉妬深い"
#   },
#   {
#     "japanese": "jelly",
#     "english": "ゼリー・ジャム"
#   },
#   {
#     "japanese": "jewel",
#     "english": "宝石・貴重な物"
#   },
#   {
#     "japanese": "joggle",
#     "english": "軽く揺する"
#   },
#   {
#     "japanese": "join",
#     "english": "結合する・参加する"
#   },
#   {
#     "japanese": "jolt",
#     "english": "ガタガタ揺する・衝撃を与える"
#   },
#   {
#     "japanese": "journey",
#     "english": "旅行"
#   },
#   {
#     "japanese": "joy",
#     "english": "喜び"
#   },
#   {
#     "japanese": "junior",
#     "english": "年下の"
#   },
#   {
#     "japanese": "justify",
#     "english": "正当化する"
#   },
#   {
#     "japanese": "keen",
#     "english": "鋭い"
#   },
#   {
#     "japanese": "kerosene",
#     "english": "灯油・ケロシン"
#   },
#   {
#     "japanese": "knowledge",
#     "english": "知識"
#   },
#   {
#     "japanese": "labor",
#     "english": "労働"
#   },
#   {
#     "japanese": "lack",
#     "english": "欠乏"
#   },
#   {
#     "japanese": "landmass",
#     "english": "大陸"
#   },
#   {
#     "japanese": "landscape",
#     "english": "風景"
#   },
#   {
#     "japanese": "launch",
#     "english": "進水させる・発射する・世に出す・開始する"
#   },
#   {
#     "japanese": "lawyer",
#     "english": "弁護士・法律家"
#   },
#   {
#     "japanese": "lazy",
#     "english": "怠惰な"
#   },
#   {
#     "japanese": "leading",
#     "english": "指導・一流の"
#   },
#   {
#     "japanese": "lean",
#     "english": "寄りかかる"
#   },
#   {
#     "japanese": "leap",
#     "english": "跳ぶ・跳躍"
#   },
#   {
#     "japanese": "lease",
#     "english": "賃貸借・賃貸する・賃借する"
#   },
#   {
#     "japanese": "legal",
#     "english": "法律の"
#   },
#   {
#     "japanese": "lend",
#     "english": "貸す"
#   },
#   {
#     "japanese": "length",
#     "english": "長さ"
#   },
#   {
#     "japanese": "lenient",
#     "english": "寛大な"
#   },
#   {
#     "japanese": "liberty",
#     "english": "自由"
#   },
#   {
#     "japanese": "light",
#     "english": "光・明かり・明るい・軽い"
#   },
#   {
#     "japanese": "limit",
#     "english": "限度・限定する"
#   },
#   {
#     "japanese": "linguistic",
#     "english": "言語の"
#   },
#   {
#     "japanese": "liquid",
#     "english": "液体・液状の"
#   },
#   {
#     "japanese": "literal",
#     "english": "文字の"
#   },
#   {
#     "japanese": "literature",
#     "english": "文学"
#   },
#   {
#     "japanese": "load",
#     "english": "積荷・積み込む"
#   },
#   {
#     "japanese": "lose",
#     "english": "失う・負ける"
#   },
#   {
#     "japanese": "lunar",
#     "english": "月の"
#   },
#   {
#     "japanese": "lure",
#     "english": "誘惑するもの・誘惑する"
#   },
#   {
#     "japanese": "luxury",
#     "english": "贅沢"
#   },
#   {
#     "japanese": "maintain",
#     "english": "維持する"
#   },
#   {
#     "japanese": "majority",
#     "english": "大多数"
#   },
#   {
#     "japanese": "major",
#     "english": "大きいほうの"
#   },
#   {
#     "japanese": "malady",
#     "english": "病気"
#   },
#   {
#     "japanese": "male",
#     "english": "男性"
#   },
#   {
#     "japanese": "mammal",
#     "english": "哺乳動物"
#   },
#   {
#     "japanese": "management",
#     "english": "取り扱い・経営・管理"
#   },
#   {
#     "japanese": "manager",
#     "english": "管理者・課長・監督・マネージャー"
#   },
#   {
#     "japanese": "manage",
#     "english": "上手に扱う・管理する"
#   },
#   {
#     "japanese": "manufacture",
#     "english": "製造する"
#   },
#   {
#     "japanese": "massive",
#     "english": "巨大な・大規模な"
#   },
#   {
#     "japanese": "material",
#     "english": "物質・物質的な"
#   },
#   {
#     "japanese": "mate",
#     "english": "仲間・伴侶・つがい"
#   },
#   {
#     "japanese": "matter",
#     "english": "事柄・物質"
#   },
#   {
#     "japanese": "mature",
#     "english": "成熟した"
#   },
#   {
#     "japanese": "maximum",
#     "english": "最大の"
#   },
#   {
#     "japanese": "means",
#     "english": "手段"
#   },
#   {
#     "japanese": "measure",
#     "english": "測定する"
#   },
#   {
#     "japanese": "mechanical",
#     "english": "機械の"
#   },
#   {
#     "japanese": "meddle",
#     "english": "余計な世話を焼く"
#   },
#   {
#     "japanese": "medical",
#     "english": "医学の・医療の"
#   },
#   {
#     "japanese": "medium",
#     "english": "中間の・媒体"
#   },
#   {
#     "japanese": "memorize",
#     "english": "記憶する・暗記する"
#   },
#   {
#     "japanese": "memory",
#     "english": "記憶・思い出・メモリー"
#   },
#   {
#     "japanese": "mend",
#     "english": "直す"
#   },
#   {
#     "japanese": "mental",
#     "english": "心の・精神の"
#   },
#   {
#     "japanese": "mention",
#     "english": "言及する"
#   },
#   {
#     "japanese": "mere",
#     "english": "単なる"
#   },
#   {
#     "japanese": "metallic",
#     "english": "金属の"
#   },
#   {
#     "japanese": "metal",
#     "english": "金属"
#   },
#   {
#     "japanese": "method",
#     "english": "方法"
#   },
#   {
#     "japanese": "minimum",
#     "english": "最小の"
#   },
#   {
#     "japanese": "minor",
#     "english": "小さいほうの"
#   },
#   {
#     "japanese": "miracle",
#     "english": "奇跡"
#   },
#   {
#     "japanese": "mischief",
#     "english": "いたずら"
#   },
#   {
#     "japanese": "misery",
#     "english": "悲惨"
#   },
#   {
#     "japanese": "misfortune",
#     "english": "不幸・不運"
#   },
#   {
#     "japanese": "mishap",
#     "english": "災難"
#   },
#   {
#     "japanese": "modest",
#     "english": "謙虚な・控えめな"
#   },
#   {
#     "japanese": "moist",
#     "english": "湿った"
#   },
#   {
#     "japanese": "molecule",
#     "english": "分子"
#   },
#   {
#     "japanese": "monarch",
#     "english": "君主"
#   },
#   {
#     "japanese": "monopoly",
#     "english": "独占・独占権"
#   },
#   {
#     "japanese": "monthly",
#     "english": "毎月の・月一回の"
#   },
#   {
#     "japanese": "mood",
#     "english": "気分"
#   },
#   {
#     "japanese": "mortgage",
#     "english": "抵当・抵当に入れる"
#   },
#   {
#     "japanese": "motive",
#     "english": "動機"
#   },
#   {
#     "japanese": "multiply",
#     "english": "(数学)掛ける、増える、"
#   },
#   {
#     "japanese": "murder",
#     "english": "殺人・殺害する"
#   },
#   {
#     "japanese": "mutual",
#     "english": "相互の"
#   },
#   {
#     "japanese": "naked",
#     "english": "裸の"
#   },
#   {
#     "japanese": "narrow",
#     "english": "狭い、狭める"
#   },
#   {
#     "japanese": "naughty",
#     "english": "いたずら好きな"
#   },
#   {
#     "japanese": "necessity",
#     "english": "必要"
#   },
#   {
#     "japanese": "negative",
#     "english": "否定の"
#   },
#   {
#     "japanese": "negotiate",
#     "english": "交渉する"
#   },
#   {
#     "japanese": "negotiation",
#     "english": "交渉"
#   },
#   {
#     "japanese": "neighborhood",
#     "english": "近所・付近・近所の人々"
#   },
#   {
#     "japanese": "neighbor",
#     "english": "隣人"
#   },
#   {
#     "japanese": "nervous",
#     "english": "神経質な"
#   },
#   {
#     "japanese": "newborn",
#     "english": "生まれたばかりの"
#   },
#   {
#     "japanese": "noble",
#     "english": "高潔な"
#   },
#   {
#     "japanese": "nominal",
#     "english": "名ばかりの"
#   },
#   {
#     "japanese": "notorious",
# ...
#     "japanese": "revenge",
#     "english": "復讐する・復讐"
#   },
#   {
#     "japanese": "revise",
#     "english": "改訂する・修正する"
#   },
#   {
#     "japanese": "revision",
#     "english": "改訂・修正"
#   },
#   {
#     "japanese": "revolution",
#     "english": "革命・回転"
#   },
#   {
#     "japanese": "reward",
#     "english": "報酬"
#   },
#   {
#     "japanese": "ridiculous",
#     "english": "馬鹿げた"
#   },
#   {
#     "japanese": "rid",
#     "english": "取り除く・免れる"
#   },
#   {
#     "japanese": "riot",
#     "english": "暴動・暴動を起こす"
#   },
#   {
#     "japanese": "risk",
#     "english": "危険性"
#   },
#   {
#     "japanese": "ritual",
#     "english": "儀式・儀式の"
#   },
#   {
#     "japanese": "robust",
#     "english": "強健な"
#   },
#   {
#     "japanese": "rock",
#     "english": "岩・揺り動かす"
#   },
#   {
#     "japanese": "role",
#     "english": "役柄・役割"
#   },
#   {
#     "japanese": "route",
#     "english": "道・道筋"
#   },
#   {
#     "japanese": "routine",
#     "english": "決まりきった仕事"
#   },
#   {
#     "japanese": "rubber",
#     "english": "ゴム"
#   },
#   {
#     "japanese": "ruin",
#     "english": "破滅"
#   },
#   {
#     "japanese": "rural",
#     "english": "田舎の"
#   },
#   {
#     "japanese": "rust",
#     "english": "さび・錆びる"
#   },
#   {
#     "japanese": "sadness",
#     "english": "悲しみ"
#   },
#   {
#     "japanese": "salary",
#     "english": "給料"
#   },
#   {
#     "japanese": "satisfy",
#     "english": "満足させる"
#   },
#   {
#     "japanese": "scarcely",
#     "english": "ほとんど～ない・かろうじて"
#   },
#   {
#     "japanese": "scatter",
#     "english": "まく、ばらまく"
#   },
#   {
#     "japanese": "scent",
#     "english": "におい・匂いをかぐ"
#   },
#   {
#     "japanese": "scissors",
#     "english": "はさみ"
#   },
#   {
#     "japanese": "scold",
#     "english": "叱る・小言を言う"
#   },
#   {
#     "japanese": "script",
#     "english": "脚本・文字・スクリプト"
#   },
#   {
#     "japanese": "search",
#     "english": "捜す"
#   },
#   {
#     "japanese": "seek",
#     "english": "捜す"
#   },
#   {
#     "japanese": "seize",
#     "english": "つかむ"
#   },
#   {
#     "japanese": "select",
#     "english": "選ぶ"
#   },
#   {
#     "japanese": "selfish",
#     "english": "利己的な・わがままな"
#   },
#   {
#     "japanese": "senior",
#     "english": "年上の"
#   },
#   {
#     "japanese": "sentiment",
#     "english": "感情"
#   },
#   {
#     "japanese": "sericulture",
#     "english": "養蚕"
#   },
#   {
#     "japanese": "serious",
#     "english": "真面目な"
#   },
#   {
#     "japanese": "server",
#     "english": "給仕人・給仕道具・サーバー"
#   },
#   {
#     "japanese": "settle",
#     "english": "解決する"
#   },
#   {
#     "japanese": "severe",
#     "english": "厳しい"
#   },
#   {
#     "japanese": "shake",
#     "english": "振る・震える"
#   },
#   {
#     "japanese": "shimmer",
#     "english": "ちらちら光る"
#   },
#   {
#     "japanese": "shine",
#     "english": "輝く・輝き"
#   },
#   {
#     "japanese": "shiver",
#     "english": "震える・(粉々の)破片"
#   },
#   {
#     "japanese": "shortage",
#     "english": "不足・欠乏"
#   },
#   {
#     "japanese": "sickness",
#     "english": "病気・吐き気"
#   },
#   {
#     "japanese": "sight",
#     "english": "視覚"
#   },
#   {
#     "japanese": "significant",
#     "english": "重要な"
#   },
#   {
#     "japanese": "sign",
#     "english": "記号・しるし・署名する"
#   },
#   {
#     "japanese": "silly",
#     "english": "愚かな"
#   },
#   {
#     "japanese": "similar",
#     "english": "類似した"
#   },
#   {
#     "japanese": "sin",
#     "english": "(宗教・道徳上の)罪"
#   },
#   {
#     "japanese": "situation",
#     "english": "立場・状況"
#   },
#   {
#     "japanese": "skill",
#     "english": "技能"
#   },
#   {
#     "japanese": "slave",
#     "english": "奴隷"
#   },
#   {
#     "japanese": "smell",
#     "english": "におい・匂いを感じる"
#   },
#   {
#     "japanese": "sniff",
#     "english": "(くんくんと)匂いを嗅ぐ"
#   },
#   {
#     "japanese": "social",
#     "english": "社会の・社交的な"
#   },
#   {
#     "japanese": "society",
#     "english": "社会・協会・学会"
#   },
#   {
#     "japanese": "solar",
#     "english": "太陽の"
#   },
#   {
#     "japanese": "solid",
#     "english": "固体の・固体"
#   },
#   {
#     "japanese": "solution",
#     "english": "解・解決法"
#   },
#   {
#     "japanese": "sorrow",
#     "english": "悲しみ"
#   },
#   {
#     "japanese": "soul",
#     "english": "魂"
#   },
#   {
#     "japanese": "source",
#     "english": "源泉"
#   },
#   {
#     "japanese": "sovereign",
#     "english": "主権者・元首"
#   },
#   {
#     "japanese": "special",
#     "english": "特別な・特殊な"
#   },
#   {
#     "japanese": "species",
#     "english": "種"
#   },
#   {
#     "japanese": "specific",
#     "english": "明確な"
#   },
#   {
#     "japanese": "spectator",
#     "english": "観客"
#   },
#   {
#     "japanese": "spiral",
#     "english": "螺旋・螺旋状の"
#   },
#   {
#     "japanese": "spiritual",
#     "english": "精神的な"
#   },
#   {
#     "japanese": "spirit",
#     "english": "精神・霊"
#   },
#   {
#     "japanese": "splendid",
#     "english": "華麗な"
#   },
#   {
#     "japanese": "spoil",
#     "english": "台無しにする"
#   },
#   {
#     "japanese": "spontaneous",
#     "english": "自発的な"
#   },
#   {
#     "japanese": "stagnation",
#     "english": "澱み・停滞"
#   },
#   {
#     "japanese": "stamina",
#     "english": "持久力"
#   },
#   {
#     "japanese": "stare",
#     "english": "じっと見つめる"
#   },
#   {
#     "japanese": "startle",
#     "english": "びっくりさせる"
#   },
#   {
#     "japanese": "starve",
#     "english": "餓死する"
#   },
#   {
#     "japanese": "statement",
#     "english": "陳述・声明・計算書"
#   },
#   {
#     "japanese": "state",
#     "english": "状態・国・州・述べる"
#   },
#   {
#     "japanese": "status",
#     "english": "地位・身分・状態"
#   },
#   {
#     "japanese": "steel",
#     "english": "鋼鉄・鋼鉄製の"
#   },
#   {
#     "japanese": "stench",
#     "english": "悪臭"
#   },
#   {
#     "japanese": "stern",
#     "english": "厳格な"
#   },
#   {
#     "japanese": "stink",
#     "english": "悪臭を放つ"
#   },
#   {
#     "japanese": "storage",
#     "english": "貯蔵・保管・倉庫・記憶装置"
#   },
#   {
#     "japanese": "store",
#     "english": "店・蓄える"
#   },
#   {
#     "japanese": "strategy",
#     "english": "戦略"
#   },
#   {
#     "japanese": "strength",
#     "english": "力・強さ"
#   },
#   {
#     "japanese": "strict",
#     "english": "厳しい"
#   },
#   {
#     "japanese": "struggle",
#     "english": "もがく"
#   },
#   {
#     "japanese": "stupid",
#     "english": "愚かな"
#   },
#   {
#     "japanese": "subcontinent",
#     "english": "亜大陸"
#   },
#   {
#     "japanese": "subject",
#     "english": "主題・服従させる"
#   },
#   {
#     "japanese": "subscribe",
#     "english": "寄付する、購読する"
#   },
#   {
#     "japanese": "substance",
#     "english": "物質"
#   },
#   {
#     "japanese": "substitute",
#     "english": "代用する"
#   },
#   {
#     "japanese": "suburb",
#     "english": "郊外"
#   },
#   {
#     "japanese": "subway",
#     "english": "地下鉄・地下道"
#   },
#   {
#     "japanese": "succeed",
#     "english": "成功する"
#   },
#   {
#     "japanese": "sufficient",
#     "english": "十分な"
#   },
#   {
#     "japanese": "suggest",
#     "english": "提案する"
#   },
#   {
#     "japanese": "sulky",
#     "english": "不機嫌な"
#   },
#   {
#     "japanese": "sultan",
#     "english": "スルターン"
#   },
#   {
#     "japanese": "summary",
#     "english": "要約・まとめ・要約した・即決の"
#   },
#   {
#     "japanese": "sunrise",
#     "english": "日の出"
#   },
#   {
#     "japanese": "sunset",
#     "english": "日没"
#   },
#   {
#     "japanese": "superior",
#     "english": "上位の"
#   },
#   {
#     "japanese": "supply",
#     "english": "供給する"
#   },
#   {
#     "japanese": "surety",
#     "english": "保証"
#   },
#   {
#     "japanese": "surface",
#     "english": "表面"
#   },
#   {
#     "japanese": "surprise",
#     "english": "驚かす・驚き"
#   },
#   {
#     "japanese": "surround",
#     "english": "取り囲む"
#   },
#   {
#     "japanese": "survey",
#     "english": "見渡す"
#   },
#   {
#     "japanese": "survive",
#     "english": "生き残る"
#   },
#   {
#     "japanese": "suspect",
#     "english": "～ではないかと思う"
#   },
#   {
#     "japanese": "sway",
#     "english": "揺らす・左右する"
#   },
#   {
#     "japanese": "swear",
#     "english": "誓う・宣誓する"
#   },
#   {
#     "japanese": "swing",
#     "english": "揺れ動く・揺り動かす"
#   },
#   {
#     "japanese": "symbolic",
#     "english": "象徴的な・記号の"
#   },
#   {
#     "japanese": "symbol",
#     "english": "象徴・記号"
#   },
#   {
#     "japanese": "sympathy",
#     "english": "同情"
#   },
#   {
#     "japanese": "tactics",
#     "english": "戦術"
#   },
#   {
#     "japanese": "talent",
#     "english": "才能・才能のある人・タレント"
#   },
#   {
#     "japanese": "taste",
#     "english": "味覚・味わう"
#   },
#   {
#     "japanese": "tax",
#     "english": "税"
#   },
#   {
#     "japanese": "temperature",
#     "english": "温度"
#   },
#   {
#     "japanese": "temper",
#     "english": "気質"
#   },
#   {
#     "japanese": "temporary",
#     "english": "一時の"
#   },
#   {
#     "japanese": "tend",
#     "english": "～する傾向がある"
#   },
#   {
#     "japanese": "tense",
#     "english": "張り詰めた・緊張する・時制"
#   },
#   {
#     "japanese": "term",
#     "english": "期間"
#   },
#   {
#     "japanese": "terrestrial",
#     "english": "地球の"
#   },
#   {
#     "japanese": "terrible",
#     "english": "ひどい・恐ろしい"
#   },
#   {
#     "japanese": "terrific",
#     "english": "素晴らしい・すごい"
#   },
#   {
#     "japanese": "territory",
#     "english": "領土・領域・縄張り"
#   },
#   {
#     "japanese": "textbook",
#     "english": "教科書"
#   },
#   {
#     "japanese": "texture",
#     "english": "質感・構造"
#   },
#   {
#     "japanese": "theater",
#     "english": "劇場"
#   },
#   {
#     "japanese": "thermometer",
#     "english": "温度計"
#   },
#   {
#     "japanese": "thickness",
#     "english": "厚さ"
#   },
#   {
#     "japanese": "thick",
#     "english": "厚い・濃い"
#   },
#   {
#     "japanese": "thin",
#     "english": "薄い"
#   },
#   {
#     "japanese": "thirsty",
#     "english": "のどが渇いた"
#   },
#   {
#     "japanese": "thought",
#     "english": "思考"
#   },
#   {
#     "japanese": "thousand",
#     "english": "1000・千"
#   },
#   {
#     "japanese": "thread",
#     "english": "糸・糸を通す"
#   },
#   {
#     "japanese": "throne",
#     "english": "玉座"
#   },
#   {
#     "japanese": "tide",
#     "english": "潮"
#   },
#   {
#     "japanese": "tidy",
#     "english": "きれい好きな・きちんとした"
#   },
#   {
#     "japanese": "tile",
#     "english": "タイル・瓦・タイルを張る"
#   },
#   {
#     "japanese": "tiny",
#     "english": "ごく小さな"
#   },
#   {
#     "japanese": "tire",
#     "english": "疲れさせる"
#   },
#   {
#     "japanese": "toddler",
#     "english": "よちよち歩きの幼児"
#   },
#   {
#     "japanese": "token",
#     "english": "しるし・証拠"
#   },
#   {
#     "japanese": "tolerance",
#     "english": "寛容"
#   },
#   {
#     "japanese": "tolerant",
#     "english": "寛容な・耐性のある"
#   },
#   {
#     "japanese": "tool",
#     "english": "道具"
#   },
#   {
#     "japanese": "top",
#     "english": "頂上・一番上の"
#   },
#   {
#     "japanese": "tour",
#     "english": "旅行・旅行する"
#   },
#   {
#     "japanese": "trace",
#     "english": "痕跡・跡を辿る"
#   },
#   {
#     "japanese": "track",
#     "english": "通り道・追跡する"
#   },
#   {
#     "japanese": "trade",
#     "english": "取引・取引する"
#   },
#   {
#     "japanese": "tradition",
#     "english": "伝統"
#   },
#   {
#     "japanese": "traffic",
#     "english": "交通"
#   },
#   {
#     "japanese": "tragedy",
#     "english": "悲劇"
#   },
#   {
#     "japanese": "training",
#     "english": "訓練"
#   },
#   {
#     "japanese": "transparent",
#     "english": "透明な"
#   },
#   {
#     "japanese": "transportation",
#     "english": "輸送"
#   },
#   {
#     "japanese": "transport",
#     "english": "輸送する"
#   },
#   {
#     "japanese": "travel",
#     "english": "旅行する・旅行"
#   },
#   {
#     "japanese": "treasure",
#     "english": "財宝"
#   },
#   {
#     "japanese": "treatment",
#     "english": "取り扱い・待遇・治療"
#   },
#   {
#     "japanese": "treaty",
#     "english": "条約"
#   },
#   {
#     "japanese": "treat",
#     "english": "取り扱う"
#   },
#   {
#     "japanese": "tremble",
#     "english": "震える"
#   },
#   {
#     "japanese": "trend",
#     "english": "傾向"
#   },
#   {
#     "japanese": "triangle",
#     "english": "三角形"
#   },
#   {
#     "japanese": "triangular",
#     "english": "三角の"
#   },
#   {
#     "japanese": "trip",
#     "english": "旅行"
#   },
#   {
#     "japanese": "triumph",
#     "english": "勝利、勝利する"
#   },
#   {
#     "japanese": "trivial",
#     "english": "些細な"
#   },
#   {
#     "japanese": "trust",
#     "english": "信頼"
#   },
#   {
#     "japanese": "twilight",
#     "english": "たそがれ"
#   },
#   {
#     "japanese": "twinkle",
#     "english": "きらきら光る・(星などの)きらめき"
#   },
#   {
#     "japanese": "tyrant",
#     "english": "暴君"
#   },
#   {
#     "japanese": "ugly",
#     "english": "醜い"
#   },
#   {
#     "japanese": "underground",
#     "english": "地下鉄・地下道・地下の・地下で"
#   },
#   {
#     "japanese": "unforgivable",
#     "english": "許されない"
#   },
#   {
#     "japanese": "ungulate",
#     "english": "有蹄動物"
#   },
#   {
#     "japanese": "unite",
#     "english": "団結する"
#   },
#   {
#     "japanese": "universe",
#     "english": "宇宙"
#   },
#   {
#     "japanese": "urban",
#     "english": "都市の・都会の"
#   },
#   {
#     "japanese": "urge",
#     "english": "駆り立てる・衝動"
#   },
#   {
#     "japanese": "urine",
#     "english": "尿"
#   },
#   {
#     "japanese": "usage",
#     "english": "使用法・慣習"
#   },
#   {
#     "japanese": "usual",
#     "english": "いつもの"
#   },
#   {
#     "japanese": "utmost",
#     "english": "最大(限度)の"
#   },
#   {
#     "japanese": "utter",
#     "english": "全くの・声を発する"
#   },
#   {
#     "japanese": "vacant",
#     "english": "空いている"
#   },
#   {
#     "japanese": "vain",
#     "english": "自惚れの強い・無駄な"
#   },
#   {
#     "japanese": "validate",
#     "english": "有効にする・正当性を立証する"
#   },
#   {
#     "japanese": "validation",
#     "english": "検証・確認・認証"
#   },
#   {
#     "japanese": "valid",
#     "english": "確かな・正当な・有効な"
#   },
#   {
#     "japanese": "value",
#     "english": "価値・評価する"
#   },
#   {
#     "japanese": "vary",
#     "english": "変える"
#   },
#   {
#     "japanese": "vegetable",
#     "english": "野菜・植物"
#   },
#   {
#     "japanese": "vehicle",
#     "english": "車両"
#   },
#   {
#     "japanese": "velocity",
#     "english": "速さ・速度"
#   },
#   {
#     "japanese": "verdict",
#     "english": "評決"
#   },
#   {
#     "japanese": "verify",
#     "english": "証明する・確認する"
#   },
#   {
#     "japanese": "versatile",
#     "english": "多才な・多用途の"
#   },
#   {
#     "japanese": "vertical",
#     "english": "垂直な"
#   },
#   {
#     "japanese": "vibrate",
#     "english": "揺れる・震動する"
#   },
#   {
#     "japanese": "victory",
#     "english": "勝利"
#   },
#   {
#     "japanese": "view",
#     "english": "見ること"
#   },
#   {
#     "japanese": "vigor",
#     "english": "精力・活力"
#   },
#   {
#     "japanese": "virtue",
#     "english": "美徳"
#   },
#   {
#     "japanese": "visible",
#     "english": "目に見える"
#   },
#   {
#     "japanese": "visitor",
#     "english": "訪問者"
#   },
#   {
#     "japanese": "visual",
#     "english": "視覚の"
#   },
#   {
#     "japanese": "vitality",
#     "english": "生命力・活力"
#   },
#   {
#     "japanese": "vital",
#     "english": "生命の"
#   },
#   {
#     "japanese": "voyage",
#     "english": "旅・航海"
#   },
#   {
#     "japanese": "vulgar",
#     "english": "下品な"
#   },
#   {
#     "japanese": "vulnerable",
#     "english": "脆弱な・傷つきやすい"
#   },
#   {
#     "japanese": "wage",
#     "english": "賃金"
#   },
#   {
#     "japanese": "wagon",
#     "english": "荷馬車"
#   },
#   {
#     "japanese": "wallet",
#     "english": "財布・札入れ"
#   },
#   {
#     "japanese": "warranty",
#     "english": "保証・認可"
#   },
#   {
#     "japanese": "warrant",
#     "english": "正当な根拠・正当化する"
#   },
#   {
#     "japanese": "waste",
#     "english": "浪費する"
#   },
#   {
#     "japanese": "waver",
#     "english": "揺らめく"
#   },
#   {
#     "japanese": "wave",
#     "english": "波・(波の様に)揺れる・手を振る"
#   },
#   {
#     "japanese": "wax",
#     "english": "蝋・ワックス・(月が)満ちる"
#   },
#   {
#     "japanese": "wealth",
#     "english": "富・財産"
#   },
#   {
#     "japanese": "weapon",
#     "english": "武器"
#   },
#   {
#     "japanese": "weather",
#     "english": "天気"
#   },
#   {
#     "japanese": "weekly",
#     "english": "毎週の・週一回の"
#   },
#   {
#     "japanese": "weight",
#     "english": "重さ"
#   },
#   {
#     "japanese": "welfare",
#     "english": "福祉"
#   },
#   {
#     "japanese": "wheel",
#     "english": "車輪"
#   },
#   {
#     "japanese": "whisper",
#     "english": "ささやく"
#   },
#   {
#     "japanese": "width",
#     "english": "幅"
#   },
#   {
#     "japanese": "wild",
#     "english": "野生の"
#   },
#   {
#     "japanese": "willing",
#     "english": "～するのをいとわない"
#   },
#   {
#     "japanese": "wince",
#     "english": "ひるむ・たじろぐ"
#   },
#   {
#     "japanese": "win",
#     "english": "勝利を得る・勝ち取る"
#   },
#   {
#     "japanese": "wisdom",
#     "english": "知恵"
#   },
#   {
#     "japanese": "workshop",
#     "english": "作業場"
#   },
#   {
#     "japanese": "worry",
#     "english": "心配させる"
#   },
#   {
#     "japanese": "worship",
#     "english": "崇拝する"
#   },
#   {
#     "japanese": "worthy",
#     "english": "価値ある"
#   },
#   {
#     "japanese": "worth",
#     "english": "～の価値がある"
#   },
#   {
#     "japanese": "wound",
#     "english": "傷つける"
#   },
#   {
#     "japanese": "wrap",
#     "english": "包む・包むもの"
#   },
#   {
#     "japanese": "wrath",
#     "english": "激怒"
#   },
#   {
#     "japanese": "yearly",
#     "english": "毎年の・年一回の"
#   },
#   {
#     "japanese": "youth",
#     "english": "若さ・若者"
#   },
#   {
#     "japanese": "treatment",
#     "english": "取り扱い・待遇・治療"
#   },
#   {
#     "japanese": "exceptional",
#     "english": "例外的な・並外れた"
#   },
#   {
#     "japanese": "exception",
#     "english": "例外・除外・異議"
#   },
#   {
#     "japanese": "except",
#     "english": "～を除いて・～でなければ"
#   },
#   {
#     "japanese": "token",
#     "english": "しるし・証拠"
#   },
#   {
#     "japanese": "gesture",
#     "english": "身ぶり・身ぶりで示す"
#   },
#   {
#     "japanese": "symbolic",
#     "english": "象徴的な・記号の"
#   },
#   {
#     "japanese": "symbol",
#     "english": "象徴・記号"
#   },
#   {
#     "japanese": "hierarchy",
#     "english": "階層・階層制度"
#   },
#   {
#     "japanese": "status",
#     "english": "地位・身分・状態"
#   }
# ]

# %%
#韓国語

import requests
from bs4 import BeautifulSoup
import json

URL = "https://coneru-web.com/hangeul-words/"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

hangul = soup.find_all("td", class_="hangeul-link_td03")
nihongo = soup.find_all("td", class_="hangeul-link_td01")

nihongo = [i for i in nihongo if "一覧" not in i.text]

# ペアを辞書として保存するためのリストを作成
word_pairs = []

for i, k in zip(hangul, nihongo):
    hangul_word = i.text
    nihongo_word = k.text

    # 各ペアのための辞書を作成
    word_pair_dict = {"hangul": hangul_word, "nihongo": nihongo_word}

    # 辞書をリストに追加
    word_pairs.append(word_pair_dict)

# JSONデータをファイルに保存
with open("kankokugo.json", "w", encoding="utf-8") as json_file:
    json.dump(word_pairs, json_file, ensure_ascii=False, indent=2)

# %%
#国民の祝日

URL = "https://www8.cao.go.jp/chosei/shukujitsu/gaiyou.html"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

data = soup.find_all("table")[1].find("tbody").find_all("tr")
meisyo = [i.find("th").text for i in data if "休日" not in i.text]
date = [i.find("td").text for i in data if "休日" not in i.text]

# ペアを辞書として保存するためのリストを作成
word_pairs = []

for meisyo_word, date_word in zip(meisyo, date):


    word_pair_dict = {"meisyo": meisyo_word, "date": date_word}
    word_pairs.append(word_pair_dict)

# JSONデータをファイルに保存
with open("shukujitsu.json", "w", encoding="utf-8") as json_file:
    json.dump(word_pairs, json_file, ensure_ascii=False, indent=2)

# %%
#難読漢字
import requests
from bs4 import BeautifulSoup
import json

URL = "https://nandoq.jp/weather.html"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

moji = [i.find("b").text for i in soup.find_all("td", class_="moji")]
yomi = [i.find("b").text for i in soup.find_all("td", class_="yomi")]

word_pairs = []

for moji_word, yomi_word in zip(moji, yomi):
    word_pair_dict = {"moji": moji_word, "yomi": yomi_word}
    word_pairs.append(word_pair_dict)

# JSONデータをファイルに保存
with open("nandokukanzi.json", "w", encoding="utf-8") as json_file:
    json.dump(word_pairs, json_file, ensure_ascii=False, indent=2)

# %%
#四字熟語一覧

import requests
from bs4 import BeautifulSoup
import json

URL = "https://idiom-encyclopedia.com/spi/"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

moji = [i.text for i in soup.find_all("h4")]
imi = [i.text for i in soup.find_all("p") if i.find_previous_sibling("h4")]

word_pairs = []

for moji_word, imi_word in zip(moji, imi):
    word_pair_dict = {"moji": moji_word, "imi": imi_word}
    word_pairs.append(word_pair_dict)

# JSONデータをファイルに保存
with open("yozizyukugo.json", "w", encoding="utf-8") as json_file:
    json.dump(word_pairs, json_file, ensure_ascii=False, indent=2)
