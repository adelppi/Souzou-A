# %% [markdown]
# <a href="https://colab.research.google.com/github/adelppi/Souzou-A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
#英単語

URL = "https://tango.mage8.com/word-list"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

data = [i.text for i in soup.find_all("a")]
data = data[8:-6]

for i in data:
  print(i.split("　"))
# Out:
# ['abandon', '捨てる']
# ['abdomen', '腹部']
# ['ability', '能力']
# ['abolish', '廃止する']
# ['abolition', '廃止']
# ['absolute', '絶対の']
# ['absorb', '吸収する']
# ['abstract', '抽象的な・取り出す']
# ['absurd', '不合理な']
# ['abundant', '豊富な']
# ['accept', '受け入れる']
# ['accessory', '付属品・アクセサリー']
# ['access', '接近・利用・接近する・利用する']
# ['accompany', '同行する']
# ['accomplish', '成し遂げる']
# ['account', '会計・口座・説明する']
# ['accurate', '正確な・精密な']
# ['accuse', '告訴する・非難する']
# ['achieve', '成し遂げる']
# ['acquaintance', '知人']
# ['acquire', '得る・身につける']
# ['activate', '活動的にする・作動させる']
# ['activation', '活性化・アクティベーション']
# ['active', '活動的な']
# ['actual', '実際の・現実の']
# ['adapt', '適合させる']
# ['additional', '付加的な・追加の']
# ['addition', '付加・足し算']
# ['add', '加える']
# ['adjustment', '調整・調節']
# ['adjust', '調節する']
# ['administer', '管理する・統治する・投薬する']
# ['administration', '管理・運営・行政・投薬']
# ['administrator', '管理者']
# ['admire', '感心する']
# ['adolescence', '青年期']
# ['adopt', '採用する']
# ['adorable', '崇拝すべき、かわいらしい']
# ['adult', '大人・大人の']
# ['advance', '進める']
# ['adverse', '逆らう・反対の']
# ['adversity', '逆境']
# ['advice', '忠告・助言・通知']
# ['advise', '忠告する']
# ['affection', '愛情']
# ['afford', '～する余裕がある']
# ['afraid', '恐れて']
# ['agree', '同意する']
# ['agriculture', '農業']
# ['aid', '助ける']
# ['ailment', '病気・体調不良']
# ['aim', '狙う']
# ['allow', '許す']
# ['alloy', '合金・合金を作る']
# ['alternate', '交互の']
# ['altitude', '高度']
# ['amalgamation', '(会社などの)合併、融合']
# ['amaze', 'びっくりさせる・驚き']
# ['ambition', '野心・大望']
# ['amenity', '心地よさ']
# ['amiable', '愛想の良い']
# ['amount', '総計']
# ['analysis', '分析']
# ['ancestor', '祖先']
# ['ancient', '古代の']
# ['anger', '怒り']
# ['annoy', 'いらだたせる']
# ['annual', '1年の、年1回の']
# ['annuity', '年金']
# ['anonymous', '匿名の']
# ['anticlimax', 'あっけない結末']
# ['anxious', '心配して']
# ['apparent', '明白な・外見上の']
# ['appear', '現れる']
# ['appetite', '食欲・欲望']
# ['applicant', '応募者・志願者']
# ['apply', '適用する・申し込む']
# ['appointment', '任命・約束・予約']
# ['appoint', '任命する']
# ['appreciate', '評価する']
# ['approval', '賛成・承認']
# ['approve', '良いと認める・賛成する']
# ['approximately', 'おおよそ・ほぼ']
# ['approximate', 'おおよその・近い']
# ['archaic', '古風な']
# ['architecture', '建築術']
# ['area', '面積・地域']
# ['argue', '議論する']
# ['argument', '議論・口論・論拠']
# ['arise', '起こる']
# ['arm', '腕・武器']
# ['arrogant', '横柄な・傲慢な']
# ['article', '記事・条項']
# ['artificial', '人工の']
# ['ashamed', '恥じて']
# ['aspect', '面・様相']
# ['assault', '急襲・襲う']
# ['associate', '交際する']
# ['assume', '～であると仮定する']
# ['assurance', '保証・確信']
# ['assure', '保証する']
# ['astonish', '驚かす']
# ['astound', '仰天させる']
# ['astronomy', '天文学']
# ['atmosphere', '大気']
# ['attack', '攻撃する・攻撃']
# ['attain', '達成する・到達する']
# ['attempt', '試みる・試み']
# ['attend', '出席する']
# ['attorney', '法定代理人・弁護士']
# ['audience', '聴衆']
# ['authenticity', '確実性']
# ['authentic', '真正の・本物の']
# ['authority', '権威']
# ['author', '著者']
# ['autocrat', '専制君主']
# ['available', '利用できる']
# ['avarice', '強欲']
# ['avenge', '報復する']
# ['average', '平均の']
# ['avoid', '避ける']
# ['awake', '起こす']
# ['award', '授与する']
# ['aware', '気づいて・知って']
# ['baby', '赤ん坊']
# ['baggage', '手荷物']
# ['bandage', '包帯・包帯をする']
# ['barely', 'かろうじて']
# ['bare', '裸の']
# ['basic', '基礎の・基礎']
# ['beam', '光線・梁']
# ['beard', 'ひげ・あごひげ']
# ['beat', '叩く・(相手を)負かす']
# ['behave', '振る舞う']
# ['belief', '信じること']
# ['belong', '属する']
# ['bend', '曲げる']
# ['beneficial', '有益な']
# ['benefit', '利益']
# ['benevolent', '慈悲深い']
# ['beware', '注意する・用心する']
# ['bewilder', '当惑させる']
# ['bias', '偏向・～を偏らせる']
# ['biography', '伝記']
# ['boldness', '大胆さ']
# ['bold', '大胆な']
# ['bookshelf', '本棚']
# ['border', 'へり・国境']
# ['borrower', '借り手']
# ['borrow', '借りる']
# ['botany', '植物学']
# ['bother', '悩ます・邪魔する']
# ['bottom', '底']
# ['bound', '縛られた・はずむ・境界・～行きで']
# ['bow', 'おじぎする']
# ['boy', '男の子・少年']
# ['bravery', '勇敢さ']
# ['brave', '勇敢な']
# ['bribery', '贈収賄']
# ['bribe', '賄賂・贈賄する']
# ['brief', '手短な']
# ['bright', '明るい']
# ['broad', '広い']
# ['browser', 'ブラウザー']
# ['browse', '(家畜が)草を食べる・ざっと目を通す・見て回る']
# ['budget', '予算(案)']
# ['burden', '荷物']
# ['butter', 'バター']
# ['calamity', '災難']
# ['calculate', '計算する']
# ['caller', '電話をかける人']
# ['camel', 'ラクダ・駱駝']
# ['candle', '蝋燭']
# ['capability', '能力・性能']
# ['capable', '有能な']
# ['capacity', '収容力・容量・能力・資格']
# ['capital', '主要な・首都']
# ['careless', '不注意な']
# ['cargo', '貨物']
# ['carriage', '馬車・台車']
# ['cart', '荷車・カート']
# ['casual', '思いつきの']
# ['catastrophe', '大惨事']
# ['cause', '原因・～を引き起こす']
# ['caution', '用心・警告・警告する']
# ['cease', '終える・止める']
# ['celestial', '天の']
# ['certain', '確かな']
# ['certificate', '証明書']
# ['certify', '証明する・認証する']
# ['charcoal', '木炭']
# ['charge', '代金を請求する・責任を負わせる・料金・責任']
# ['chart', '図表・グラフ・海図・カルテ']
# ['cheap', '安い']
# ['child', '子供']
# ['circle', '円・回る']
# ['circuit', '巡回・回路']
# ['circular', '円形の・回覧の']
# ['circulate', '循環する・流布する']
# ['circulation', '循環']
# ['circumstance', '状況']
# ['claim', '要求する']
# ['client', '依頼人・顧客']
# ['cloth, clothes', '布・衣服']
# ['clue', '手がかり']
# ['cluster', '群れ・一団・群がる']
# ['coal', '石炭']
# ['colleague', '同僚']
# ['collect', '集める']
# ['comedy', '喜劇']
# ['comfort', '快適・慰める']
# ['commerce', '商業']
# ['commit', '(罪などを)犯す']
# ['common', '共通の・公共の']
# ['communicate', '伝達する・通じ合う']
# ['companion', '仲間・伴侶']
# ['compare', '比較する']
# ['comparison', '比較']
# ['compassion', '同情']
# ['compel', '強いる・強要する']
# ['compete', '競争する']
# ['complain', '不平を言う']
# ['complete', '完全な・完了する']
# ['complex', '複雑な']
# ['component', '構成要素・成分・部品']
# ['compose', '構成する']
# ['comprehensive', '包括的な']
# ['compromise', '妥協する']
# ['comrade', '僚友・同志']
# ['conceal', '隠す']
# ['conceive', '思い描く']
# ['concentrate', '集中する']
# ['concern', '関係している']
# ['conclude', '(言動を)終える・結論を下す']
# ['conclusion', '終わり・結論']
# ['conference', '会議・協議']
# ['confine', '制限する・境界']
# ['confirmation', '確認・確証']
# ['confirm', '確認する・確証する']
# ['conflict', '争い']
# ['confront', '対面する']
# ['confuse', '混乱させる']
# ['conquer', '征服する']
# ['conscience', '良心']
# ['consensus', '(意見などの)一致']
# ['consequence', '結果']
# ['considerable', '考慮すべき・(数量が)かなりの']
# ['constitute', '構成する']
# ['construction', '建造']
# ['constructive', '建設的な']
# ['construct', '建設する・組み立てる']
# ['consultant', '相談相手・コンサルタント']
# ['consult', '(専門家に)意見を聞く・相談する']
# ['consume', '消費する']
# ['contemporary', '同時代の']
# ['continent', '大陸']
# ['continue', '続ける']
# ['contrary', '反対の']
# ['contrast', '対照する・対比する・対照・対比']
# ['contribute', '寄付する']
# ['convenient', '便利な']
# ['conversation', '会話・対話']
# ['convince', '確信させる']
# ['cooperate', '協力する']
# ['core', '(果物の)芯・核心']
# ['correction', '訂正・修正・補正・矯正']
# ['correct', '正しい・訂正する']
# ['correspond', '一致する・文通する']
# ['courage', '勇気']
# ['courtesy', '礼儀']
# ['cousin', 'いとこ・従兄弟・従姉妹']
# ['create', '創造する']
# ['creep', '這う']
# ['crime', '犯罪']
# ['criminal', '犯罪者・犯罪の']
# ['crisis', '危機']
# ['criticism', '批判']
# ['cruel', '残酷な・無慈悲な']
# ['crunch', 'ばりばりと食べる']
# ['crust', '外皮・パンの耳']
# ['cultivate', '耕作する']
# ['cultural', '文化の']
# ['cure', '治療する']
# ['curious', '好奇心の強い']
# ['customer', '顧客・お客']
# ['custom', '慣習']
# ['daily', '毎日の・日常の']
# ['danger', '危険']
# ['dawn', '夜明け']
# ['daybreak', '夜明け']
# ['debate', '討論する']
# ['decadence', '衰退、退廃']
# ['decade', '10年間']
# ['deceive', '騙す']
# ['decide', '決める']
# ['decipher', '解読する']
# ['decision', '決定・決断・決意・判決']
# ['decisive', '決定的な・決断力のある']
# ['declare', '宣言する']
# ['decline', '辞退する']
# ['decrease', '減る']
# ['deed', '行い・捺印証書']
# ['defeat', '(相手を)負かす・敗北']
# ['defect', '欠点']
# ['defendant', '被告・被告の']
# ['defend', '守る']
# ['define', '定義する']
# ['deflate', 'しぼませる']
# ['deflation', 'デフレーション・収縮']
# ['degree', '程度']
# ['delay', '遅らせる']
# ['delegate', '代表者']
# ['delight', '喜び・喜ばす']
# ['deliver', '配達する']
# ['demand', '要求する・要求']
# ['dense', '濃密な']
# ['density', '密度・濃度']
# ['deny', '否定する']
# ['department', '部門・部局']
# ['depart', '出発する・逸脱する']
# ['depend', '頼る']
# ['depressed', '落ち込んで']
# ['depression', '意気消沈・不景気']
# ['depress', '落ち込ませる・押し下げる']
# ['depth', '深さ']
# ['derive', '引き出す・由来する']
# ['descendant', '子孫']
# ['describe', '記述する']
# ['description', '記述・説明']
# ['desire', '欲望・欲する']
# ['despair', '絶望']
# ['despise', '軽蔑する']
# ['despot', '専制君主']
# ['destiny', '運命']
# ['destroy', '破壊する']
# ['destruction', '破壊']
# ['destructive', '破壊的な']
# ['detail', '細部']
# ['detergent', '洗剤']
# ['determine', '決定する・決心する']
# ['deter', '抑止する']
# ['develop', '発達させる']
# ['device', '装置']
# ['devote', '(心身を)捧げる']
# ['diagram', '図・図形']
# ['dialect', '方言']
# ['dictator', '独裁者']
# ['different', '違う']
# ['differ', '違う']
# ['dignity', '威厳']
# ['diligent', '勤勉な']
# ['diminish', '減らす']
# ['diplomacy', '外交']
# ['diplomatic', '外交上の']
# ['disappointment', '失望']
# ['disappoint', '失望させる']
# ['disaster', '災害']
# ['discipline', '訓練']
# ['discourage', '失望させる']
# ['disease', '病気・疾患']
# ['dismiss', '解散させる・退ける']
# ['display', '陳列する']
# ['dispute', '論争、論じる']
# ['dissuade', '思いとどまらせる']
# ['distant', '遠い・離れた']
# ['distinguish', '区別する']
# ['distribution', '分配']
# ['district', '地区']
# ['disturb', '乱す・邪魔をする']
# ['divide', '分ける']
# ['division', '分割、区分']
# ['documentary', '文書の・ドキュメンタリー']
# ['document', '文書・書類']
# ['domestic', '家庭の']
# ['doom', '悲運']
# ['doubt', '疑う・疑い']
# ['dramatic', '劇の・劇的な']
# ['drama', '劇・ドラマ']
# ['drill', 'ドリル・訓練・穴をあける']
# ['driver', '運転手']
# ['drought', '干ばつ・渇水']
# ['due', '支払期限の来た']
# ['dull', '鈍い']
# ['duplicate', '複製する']
# ['durability', '耐久性・永続性']
# ['durable', '耐久性のある・永続的な']
# ['dusk', '夕闇']
# ['duty', '義務']
# ['eager', '熱心な']
# ['earn', '稼ぐ']
# ['earthly', '地球の・地上の']
# ['ease', '安楽・楽にする']
# ['easily', '容易に']
# ['eatable', '食べられる']
# ['eavesdrop', '立ち聞きする']
# ['echo', 'こだま・(音が)反響する']
# ['eclipse', '日食・月食']
# ['economy', '節約・経済']
# ['ecstasy', '恍惚']
# ['edible', '食べられる・食用の']
# ['editor', '編集者']
# ['educate', '教育する']
# ['education', '教育']
# ['effect', '結果・効果']
# ['elder', '年上の・年長者']
# ['election', '選挙']
# ['electricity', '電気']
# ['elegant', '上品な・優雅な']
# ['elevation', '高めること']
# ['eliminate', '除去する']
# ['eloquent', '雄弁な']
# ['embrace', '抱き締める・受け入れる']
# ['emergency', '非常時・緊急事態']
# ['emir', '(イスラム教国の)首長']
# ['emotion', '感情']
# ['emphasis', '強調']
# ['empty', '空の・空にする']
# ['enable', '可能にさせる']
# ['enclose', '同封する・取り囲む']
# ['endanger', '危険にさらす']
# ['endure', '耐える']
# ['enemy', '敵・敵の']
# ['energy', '精力・エネルギー']
# ['enforce', '(強制的に)実施する・強要する']
# ['engage', '従事する']
# ['enhancement', '向上・増進']
# ['enhance', '(価値や質を)高める']
# ['enjoyment', '楽しみ']
# ['enlargement', '拡大・増大']
# ['enlarge', '大きくする・拡大する']
# ['enormous', '巨大な']
# ['enter', '入る・記入する']
# ['enthusiasm', '熱中・熱意']
# ['enthusiastic', '熱烈な・熱中して']
# ['entire', '全体の']
# ['entrance', '入り口・入ること・うっとりさせる']
# ['entry', '入ること・入り口・記入']
# ['envelope', '封筒']
# ['envelop', '包む']
# ['environment', '環境']
# ['envy', 'ねたみ・ねたむ']
# ['epoch', '新紀元']
# ['equipment', '設備・装備・機器']
# ['equip', '備える・身につけさせる']
# ['era', '時代']
# ['escapade', '脱線行為']
# ['establish', '設立する']
# ['estimate', '見積もる']
# ['evidence', '証拠']
# ['evident', '明白な・明らかな']
# ['evil', '悪い・悪']
# ['evolve', '展開する・進化する']
# ['exact', '正確な']
# ['examine', '調査する']
# ['example', '例・実例']
# ['exceptional', '例外的な・並外れた']
# ['exception', '例外・除外・異議']
# ['except', '～を除いて・～でなければ']
# ['exchange', '交換する']
# ['excursion', '遠足']
# ['exhaustion', '消耗・疲労']
# ['exhaust', '使い尽くす']
# ['exhibit', '展示する']
# ['exist', '存在する']
# ['exit', '出口・退出・出て行く']
# ['expedient', '好都合な']
# ['expedition', '遠征']
# ['expensive', '高価な']
# ['experience', '経験']
# ['experiment', '実験・実験する']
# ['explain', '説明する']
# ['explanation', '説明']
# ['explode', '爆発する']
# ['explore', '探検する']
# ['export', '輸出する']
# ['expose', '(日光・風雨に)さらす']
# ['express', '表現する']
# ['extend', '伸ばす']
# ['extent', '広さ、程度']
# ['exterior', '外部の・外側の']
# ['external', '外部の']
# ['extinct', '絶滅した']
# ['fabulous', '伝説的な、素晴らしい']
# ['facility', '施設・設備']
# ['factory', '工場']
# ['failure', '失敗・不足・故障']
# ['fail', '失敗する']
# ['faith', '信頼・信念']
# ['fake', '偽の']
# ['familiar', 'よく知られている']
# ['famine', '飢饉']
# ['fancy', '空想・空想する']
# ['farce', '笑劇・茶番']
# ['farewell', '別れ・別れの言葉']
# ['fare', '運賃']
# ['fascinate', '魅了する']
# ['fate', '運命']
# ['fat', '太った・脂肪']
# ['favor', '好意']
# ['feast', '祝宴']
# ['feature', '特徴']
# ['feces', '糞便']
# ['fee', '料金・報酬']
# ['fellow', '男・(男の)仲間']
# ['female', '女性']
# ['fertile', '肥沃な・多産な']
# ['figure', '形・姿・数字・図で表す・計算する']
# ['financial', '財政上の']
# ['fine', '素晴らしい']
# ['firm', '硬い']
# ['fit', '適当な・適合する']
# ['fix', '固定する']
# ['flash', 'ひらめき・ひらめく']
# ['flatter', 'お世辞を言う']
# ['flavor', '風味・味わい']
# ['flicker', '揺らめく・揺らめき']
# ['flood', '洪水']
# ['fluent', '流暢な']
# ['fluid', '流体・流動性の']
# ['foe', '敵']
# ['foolish', '愚かな']
# ['force', '力・強要する']
# ['forecast', '予測する・予測']
# ['forefather', '先祖']
# ['forehead', '額・おでこ']
# ['forgetful', '忘れっぽい']
# ['forget', '忘れる']
# ['forgiveness', '許し・許すこと']
# ['forgive', '許す']
# ['formal', '正式の・形式ばった']
# ['former', '前の']
# ['fortnight', '二週間']
# ['fortune', '運']
# ['found', '創設する']
# ['fragile', '壊れやすい']
# ['fragrance', '香り']
# ['freedom', '自由']
# ['freight', '貨物輸送・運賃・積み荷']
# ['frequent', 'たびたびの']
# ['freshwater', '淡水・淡水の']
# ['fresh', '新鮮な']
# ['friend', '友達']
# ['frighten', '怖がらせる']
# ['frigid', '極寒の・冷ややかな']
# ['fuel', '燃料']
# ['fulfill', '遂行する']
# ['function', '機能']
# ['fundamental', '基本の・基本']
# ['fun', '楽しみ']
# ['furnish', '供給する']
# ['fury', '憤激']
# ['gadget', '目新しい小道具・ガジェット']
# ['gain', '得る']
# ['gasoline', 'ガソリン']
# ['gas', '気体・ガス']
# ['gather', '集める']
# ['gaze', '見つめる']
# ['generous', '気前のよい']
# ['gene', '遺伝子']
# ['genuine', '本物の']
# ['geography', '地理学']
# ['gesture', '身ぶり・身ぶりで示す']
# ['girl', '女の子・少女']
# ['glance', 'ちらりと見る']
# ['glare', 'まぶしい光']
# ['gleam', 'かすかな光']
# ['glimmer', 'かすかな光']
# ['glint', 'きらっと光る']
# ['glisten', 'きらきら輝く']
# ['glitter', 'ぴかぴか光る']
# ['global', '全世界の・地球の']
# ['globe', '球・地球']
# ['glow', '白熱光']
# ['govern', '統治する']
# ['graduate', '卒業する']
# ['grain', '穀物']
# ['grateful', '感謝している']
# ['grate', 'すりおろす・火格子']
# ['gravitation', '引力・重力']
# ['greed', '貪欲']
# ['greet', 'あいさつする']
# ['grief', '悲嘆']
# ['grocery', '食料雑貨店']
# ['guarantee', '保証・保証する']
# ['guaranty', '保証']
# ['guardian', '保護者・守護者・後見人']
# ['guard', '守る・見張る・護衛・見張り']
# ['guess', '推測する']
# ['guest', '招待客']
# ['guilty', '有罪の']
# ['gulp', 'ごくごく飲む・がつがつ食べる']
# ['habit', '習慣']
# ['hardly', 'ほとんど～ない']
# ['harm', '害する']
# ['harsh', '厳しい・不快な']
# ['harvest', '収穫']
# ['hate', '憎む']
# ['hazard', '危険']
# ['headquarters', '本部・本社']
# ['hearing', '聴覚']
# ['heaven', '天国']
# ['height', '高さ']
# ['hell', '地獄']
# ['hesitate', '躊躇する']
# ['hierarchy', '階層・階層制度']
# ['hinder', '妨げる']
# ['horizontal', '水平な']
# ['horizon', '地平線']
# ['horrible', '恐ろしい・ひどい']
# ['horrific', '恐ろしい・身の毛もよだつ']
# ['hostile', '敵の・敵意のある']
# ['huge', '巨大な']
# ['humble', '謙虚な']
# ['hungry', '飢えた・腹の減った']
# ['hurt', '怪我をさせる']
# ['hydrogen', '水素']
# ['ideal', '理想・理想的な']
# ['identify', '見分ける']
# ['ignorance', '無知']
# ['ignorant', '無知な']
# ['ignore', '無視する']
# ['illness', '病気']
# ['illuminate', '光を照らす']
# ['imagine', '想像する']
# ['imbecile', '低脳な']
# ['imitate', '模倣する']
# ['impede', '妨げる']
# ['imperil', '危険にさらす']
# ['implement', '道具・実行する']
# ['importance', '重要性・大切さ']
# ['important', '重要な・大切な']
# ['import', '輸入する']
# ['impress', '印象を与える・感動させる']
# ['improper', '不適当な']
# ['impudent', '厚かましい']
# ['inability', '能力の欠如']
# ['incentive', '動機・刺激']
# ['inclement', '(天候が)荒れ模様の']
# ['include', '含む']
# ['income', '収入']
# ['increase', '増える']
# ['independent', '独立した']
# ['index', '索引・指針・指数']
# ['indicate', '指し示す']
# ['indifferent', '無関心な']
# ['individual', '個々の']
# ['industry', '産業']
# ['infant', '幼児']
# ['inferior', '下位の']
# ['infinite', '無限の']
# ['inflate', '膨らませる']
# ['inflation', 'インフレーション・膨張']
# ['influence', '影響']
# ['informal', '非公式の・略式の']
# ['inform', '知らせる']
# ['inherit', '相続する']
# ['inhibit', '抑制する']
# ['injection', '注入・注射']
# ['inject', '注入する・注射する']
# ['injure', '傷つける']
# ['innovate', '革新する']
# ['innovation', '革新']
# ['inquire', '尋ねる・調査する']
# ['insert', '挿入する']
# ['inside', '内部・内側の']
# ['insist', '主張する']
# ['insoluble', '解決できない']
# ['inspection', '検査・視察']
# ['inspect', '検査する・視察する']
# ['instance', '例・実例']
# ['instead', '代わりに']
# ['instinct', '本能']
# ['instruction', '指示']
# ['instrument', '器具']
# ['insult', '侮辱する・侮辱']
# ['insurance', '保険']
# ['integrity', '高潔・完全性']
# ['intellectual', '知的な']
# ['intelligence', '知能']
# ['intelligent', '聡明な']
# ['intense', '激しい']
# ['interest', '興味・利益']
# ['interfere', '邪魔をする']
# ['interior', '内部の・内側の']
# ['intermission', '休止・中断']
# ['intermittent', '断続的な']
# ['internal', '内部の']
# ['interpose', '間に置く・間に割って入る']
# ['interpret', '解釈する・通訳する']
# ['interval', '間隔']
# ['introduce', '紹介する']
# ['introspective', '内省的な']
# ['intuition', '直感']
# ['invalidate', '無効にする']
# ['invalid', '無効な・病弱な']
# ['invent', '発明する']
# ['investigate', '調査する']
# ['investigation', '調査・研究・捜査']
# ['investor', '投資家']
# ['invite', '招待する']
# ['involve', '巻き込む']
# ['iron', '鉄・鉄製の・アイロンをかける']
# ['isolated', '孤立した・隔離された']
# ['isolate', '孤立させる']
# ['isolation', '分離・孤立']
# ['issue', '発行・出版する']
# ['jackpot', '大当たり']
# ['jealous', '嫉妬深い']
# ['jelly', 'ゼリー・ジャム']
# ['jewel', '宝石・貴重な物']
# ['joggle', '軽く揺する']
# ['join', '結合する・参加する']
# ['jolt', 'ガタガタ揺する・衝撃を与える']
# ['journey', '旅行']
# ['joy', '喜び']
# ['junior', '年下の']
# ['justify', '正当化する']
# ['keen', '鋭い']
# ['kerosene', '灯油・ケロシン']
# ['knowledge', '知識']
# ['labor', '労働']
# ['lack', '欠乏']
# ['landmass', '大陸']
# ['landscape', '風景']
# ['launch', '進水させる・発射する・世に出す・開始する']
# ['lawyer', '弁護士・法律家']
# ['lazy', '怠惰な']
# ['leading', '指導・一流の']
# ['lean', '寄りかかる']
# ['leap', '跳ぶ・跳躍']
# ['lease', '賃貸借・賃貸する・賃借する']
# ['legal', '法律の']
# ['lend', '貸す']
# ['length', '長さ']
# ['lenient', '寛大な']
# ['liberty', '自由']
# ['light', '光・明かり・明るい・軽い']
# ['limit', '限度・限定する']
# ['linguistic', '言語の']
# ['liquid', '液体・液状の']
# ['literal', '文字の']
# ['literature', '文学']
# ['load', '積荷・積み込む']
# ['lose', '失う・負ける']
# ['lunar', '月の']
# ['lure', '誘惑するもの・誘惑する']
# ['luxury', '贅沢']
# ['maintain', '維持する']
# ['majority', '大多数']
# ['major', '大きいほうの']
# ['malady', '病気']
# ['male', '男性']
# ['mammal', '哺乳動物']
# ['management', '取り扱い・経営・管理']
# ['manager', '管理者・課長・監督・マネージャー']
# ['manage', '上手に扱う・管理する']
# ['manufacture', '製造する']
# ['massive', '巨大な・大規模な']
# ['material', '物質・物質的な']
# ['mate', '仲間・伴侶・つがい']
# ['matter', '事柄・物質']
# ['mature', '成熟した']
# ['maximum', '最大の']
# ['means', '手段']
# ['measure', '測定する']
# ['mechanical', '機械の']
# ['meddle', '余計な世話を焼く']
# ['medical', '医学の・医療の']
# ['medium', '中間の・媒体']
# ['memorize', '記憶する・暗記する']
# ['memory', '記憶・思い出・メモリー']
# ['mend', '直す']
# ['mental', '心の・精神の']
# ['mention', '言及する']
# ['mere', '単なる']
# ['metallic', '金属の']
# ['metal', '金属']
# ['method', '方法']
# ['minimum', '最小の']
# ['minor', '小さいほうの']
# ['miracle', '奇跡']
# ['mischief', 'いたずら']
# ['misery', '悲惨']
# ['misfortune', '不幸・不運']
# ['mishap', '災難']
# ['modest', '謙虚な・控えめな']
# ['moist', '湿った']
# ['molecule', '分子']
# ['monarch', '君主']
# ['monopoly', '独占・独占権']
# ['monthly', '毎月の・月一回の']
# ['mood', '気分']
# ['mortgage', '抵当・抵当に入れる']
# ['motive', '動機']
# ['multiply', '(数学)掛ける、増える、']
# ['murder', '殺人・殺害する']
# ['mutual', '相互の']
# ['naked', '裸の']
# ['narrow', '狭い、狭める']
# ['naughty', 'いたずら好きな']
# ['necessity', '必要']
# ['negative', '否定の']
# ['negotiate', '交渉する']
# ['negotiation', '交渉']
# ['neighborhood', '近所・付近・近所の人々']
# ['neighbor', '隣人']
# ['nervous', '神経質な']
# ['newborn', '生まれたばかりの']
# ['noble', '高潔な']
# ['nominal', '名ばかりの']
# ['notorious', '悪名高い']
# ['obedience', '服従・恭順']
# ['obedient', '従順な']
# ['obey', '従う・服従する']
# ['objectivity', '客観性']
# ['obligation', '義務']
# ['oblige', '義務を負わせる']
# ['oblivion', '忘却']
# ['observation', '観察・観測・監視']
# ['observer', '観察者・監視者']
# ['observe', '観察する・(規則や習慣を)守る']
# ['obsolete', '廃れた・時代遅れの']
# ['obstruct', '(道を)ふさぐ・妨害する']
# ['obtain', '得る']
# ['occupy', '占領する']
# ['occur', '起こる']
# ['odd', '変な・奇数の']
# ['odor', 'におい']
# ['offer', '提供する']
# ['offspring', '子・子孫']
# ['operate', '運転する']
# ['opinion', '意見・考え']
# ['opportunity', '機会']
# ['opposite', '反対(側)の']
# ['optimism', '楽天主義・楽観論']
# ['oral', '口の・口頭の']
# ['orbit', '軌道']
# ['ordinary', '普通の']
# ['organic', '有機の・有機的な']
# ['organization', '組織・団体']
# ['organize', '組織する']
# ['origin', '起源']
# ['outside', '外部・外側の']
# ['overcome', '打ち勝つ・克服する']
# ['overture', '提案、予備交渉']
# ['owe', '借りている']
# ['ownership', '所有権']
# ['owner', '所有者・持ち主']
# ['own', '自分自身の・所有する']
# ['paradox', '逆説・パラドックス']
# ['paraffin', '灯油・パラフィン']
# ['parallel', '平行な']
# ['participate', '参加する']
# ['particular', '特定の']
# ['passenger', '乗客']
# ['passion', '情熱']
# ['pastime', '娯楽']
# ['pathetic', '哀れな']
# ['patient', '我慢強い・患者']
# ['payment', '支払い・報い']
# ['pay', '支払う・給料']
# ['peculiar', '奇妙な・独特の']
# ['pedestrian', '歩行者、徒歩の']
# ['pendulum', '振り子']
# ['pension', '年金']
# ['perceive', '知覚する']
# ['perception', '知覚']
# ['peril', '危険']
# ['period', '期間・ピリオド']
# ['permanent', '永久的な・常設の']
# ['permit', '許す']
# ['perpetual', '永久の・絶え間ない']
# ['persist', '固執する']
# ['personal', '個人の']
# ['persuade', '説得する']
# ['pessimism', '悲観主義・悲観論']
# ['petroleum', '石油']
# ['petrol', 'ガソリン']
# ['phenomenon', '現象・事象']
# ['physical', '物質の・身体の']
# ['pity', 'あわれみ']
# ['plaintiff', '原告']
# ['planetary', '惑星の']
# ['pleasure', '楽しみ']
# ['plunder', '略奪する・略奪']
# ['polish', '磨く']
# ['polite', '礼儀正しい']
# ['political', '政治の']
# ['pollution', '汚染']
# ['population', '人口']
# ['positive', '確かな']
# ['possess', '所有する']
# ['posterity', '後世の人々']
# ['postpone', '延期する']
# ['potential', '潜在的な・潜在力']
# ['pour', '注ぐ']
# ['poverty', '貧乏・貧困']
# ['power', '力']
# ['practice', '練習[実践]する']
# ['praise', '称賛する']
# ['prank', 'いたずら']
# ['precious', '貴重な']
# ['precise', '正確な']
# ['predator', '捕食動物']
# ['predict', '予言する']
# ['prefecture', '県']
# ['prefer', '(むしろ)～の方を好む']
# ['prejudice', '偏見・偏見を持たせる']
# ['prepare', '準備する']
# ['preschool', '就学前の']
# ['presence', '存在']
# ['preservation', '保存・保護']
# ['preserve', '保存する']
# ['prestige', '威信']
# ['pretend', '～のふりをする']
# ['prevail', '流行している・打ち勝つ']
# ['prevention', '防止・予防']
# ['preventive', '予防の']
# ['prevent', '妨げる・予防する']
# ['primary', '初期の・第一の']
# ['primitive', '原始の']
# ['principal', '主要な']
# ['privacy', 'プライバシー']
# ['private', '私的な・民間の']
# ['privilege', '特権']
# ['proceeding', '手続き・訴訟']
# ['proceed', '続行する・前進する']
# ['produce', '生産する']
# ['profession', '職業']
# ['profit', '利益']
# ['prolong', '長引かせる・延長する']
# ['promote', '昇進させる']
# ['pronounce', '発音する']
# ['proper', '適切な']
# ['propose', '提案する']
# ['prosecute', '起訴する']
# ['prosecutor', '検察官・検事']
# ['prosperity', '繁栄']
# ['prosper', '繁栄する・繁盛する']
# ['proverb', 'ことわざ']
# ['prove', '証明する']
# ['provide', '提供する']
# ['prudence', '思慮分別']
# ['psychology', '心理学']
# ['puberty', '思春期']
# ['publicity', '広報・宣伝']
# ['public', '公の・公的な・公衆']
# ['publish', '出版する']
# ['punctual', '時間に正確な']
# ['punish', '罰する']
# ['purchase', '購入する']
# ['purpose', '目的']
# ['quake', '(地面などが)揺れる・地震']
# ['qualify', '資格を与える、資格を得る']
# ['quality', '質・品質']
# ['quantity', '量']
# ['quantum', '量子・量']
# ['quarter', '4分の1']
# ['questionnaire', 'アンケート']
# ['quiver', '震える・矢筒']
# ['quota', '割り当て']
# ['quote', '引用する']
# ['rage', '激怒']
# ['raja', '藩王']
# ['rapid', '迅速な']
# ['rapture', '狂喜']
# ['rare', 'まれな']
# ['rashness', '無分別']
# ['ratify', '(条約を)批准する']
# ['rational', '理性的な']
# ['ray', '光線・エイ']
# ['razor', '剃刀・カミソリ']
# ['reaction', '反応・反作用']
# ['react', '反応する']
# ['reality', '現実']
# ['reason', '理由']
# ['rebellion', '反乱・反抗']
# ['recall', '思い出す・呼び戻す']
# ['recent', '最近の']
# ['recession', '景気後退']
# ['referendum', '国民投票']
# ['refer', '言及する']
# ['reflect', '反射する']
# ['refreshment', '元気回復・軽食']
# ['refresh', '元気を回復する・新たにする']
# ['refuse', '断る']
# ['regard', '見なす']
# ['region', '地方']
# ['regret', '後悔する']
# ['reign', '君臨・君臨する']
# ['reinforce', '補強する・増強する']
# ['relate', '関係させる']
# ['release', '解放する']
# ['reliability', '信頼性']
# ['reliable', '頼りになる・信頼できる']
# ['religion', '宗教']
# ['rely', '頼る']
# ['remind', '思い出させる']
# ['removable', '取り外しできる']
# ['removal', '除去・撤去・移転']
# ['remove', '取り去る・移動させる']
# ['repair', '修繕する']
# ['repay', '返金する']
# ['repetitious', '繰り返しの多い']
# ['replace', '取って代わる・取り替える']
# ['reply', '答える']
# ['reputation', '評判']
# ['requirement', '要求、必要条件']
# ['require', '必要とする・要求する']
# ['research', '研究・研究する']
# ['resemble', '～に似ている']
# ['resent', '憤慨する']
# ['residence', '住宅・居住']
# ['residential', '住宅の・居住の']
# ['resident', '居住している・居住者']
# ['reside', '住む・居住する']
# ['resign', '辞職する']
# ['resistance', '抵抗']
# ['resistant', '抵抗力がある・耐性のある']
# ['resist', '抵抗する']
# ['resolve', '決心する・解決する']
# ['resource', '資源']
# ['respect', '尊敬する']
# ['respond', '返答する']
# ['responsibility', '責任']
# ['responsible', '責任がある']
# ['restore', '修復する・回復する']
# ['restrain', '抑制する']
# ['restrict', '制限する']
# ['result', '結果']
# ['retaliate', '仕返しをする・報復する']
# ['reveal', '暴露する']
# ['revenge', '復讐する・復讐']
# ['revise', '改訂する・修正する']
# ['revision', '改訂・修正']
# ['revolution', '革命・回転']
# ['reward', '報酬']
# ['ridiculous', '馬鹿げた']
# ['rid', '取り除く・免れる']
# ['riot', '暴動・暴動を起こす']
# ['risk', '危険性']
# ['ritual', '儀式・儀式の']
# ['robust', '強健な']
# ['rock', '岩・揺り動かす']
# ['role', '役柄・役割']
# ['route', '道・道筋']
# ['routine', '決まりきった仕事']
# ['rubber', 'ゴム']
# ['ruin', '破滅']
# ['rural', '田舎の']
# ['rust', 'さび・錆びる']
# ['sadness', '悲しみ']
# ['salary', '給料']
# ['satisfy', '満足させる']
# ['scarcely', 'ほとんど～ない・かろうじて']
# ['scatter', 'まく、ばらまく']
# ['scent', 'におい・匂いをかぐ']
# ['scissors', 'はさみ']
# ['scold', '叱る・小言を言う']
# ['script', '脚本・文字・スクリプト']
# ['search', '捜す']
# ['seek', '捜す']
# ['seize', 'つかむ']
# ['select', '選ぶ']
# ['selfish', '利己的な・わがままな']
# ['senior', '年上の']
# ['sentiment', '感情']
# ['sericulture', '養蚕']
# ['serious', '真面目な']
# ['server', '給仕人・給仕道具・サーバー']
# ['settle', '解決する']
# ['severe', '厳しい']
# ['shake', '振る・震える']
# ['shimmer', 'ちらちら光る']
# ['shine', '輝く・輝き']
# ['shiver', '震える・(粉々の)破片']
# ['shortage', '不足・欠乏']
# ['sickness', '病気・吐き気']
# ['sight', '視覚']
# ['significant', '重要な']
# ['sign', '記号・しるし・署名する']
# ['silly', '愚かな']
# ['similar', '類似した']
# ['sin', '(宗教・道徳上の)罪']
# ['situation', '立場・状況']
# ['skill', '技能']
# ['slave', '奴隷']
# ['smell', 'におい・匂いを感じる']
# ['sniff', '(くんくんと)匂いを嗅ぐ']
# ['social', '社会の・社交的な']
# ['society', '社会・協会・学会']
# ['solar', '太陽の']
# ['solid', '固体の・固体']
# ['solution', '解・解決法']
# ['sorrow', '悲しみ']
# ['soul', '魂']
# ['source', '源泉']
# ['sovereign', '主権者・元首']
# ['special', '特別な・特殊な']
# ['species', '種']
# ['specific', '明確な']
# ['spectator', '観客']
# ['spiral', '螺旋・螺旋状の']
# ['spiritual', '精神的な']
# ['spirit', '精神・霊']
# ['splendid', '華麗な']
# ['spoil', '台無しにする']
# ['spontaneous', '自発的な']
# ['stagnation', '澱み・停滞']
# ['stamina', '持久力']
# ['stare', 'じっと見つめる']
# ['startle', 'びっくりさせる']
# ['starve', '餓死する']
# ['statement', '陳述・声明・計算書']
# ['state', '状態・国・州・述べる']
# ['status', '地位・身分・状態']
# ['steel', '鋼鉄・鋼鉄製の']
# ['stench', '悪臭']
# ['stern', '厳格な']
# ['stink', '悪臭を放つ']
# ['storage', '貯蔵・保管・倉庫・記憶装置']
# ['store', '店・蓄える']
# ['strategy', '戦略']
# ['strength', '力・強さ']
# ['strict', '厳しい']
# ['struggle', 'もがく']
# ['stupid', '愚かな']
# ['subcontinent', '亜大陸']
# ['subject', '主題・服従させる']
# ['subscribe', '寄付する、購読する']
# ['substance', '物質']
# ['substitute', '代用する']
# ['suburb', '郊外']
# ['subway', '地下鉄・地下道']
# ['succeed', '成功する']
# ['sufficient', '十分な']
# ['suggest', '提案する']
# ['sulky', '不機嫌な']
# ['sultan', 'スルターン']
# ['summary', '要約・まとめ・要約した・即決の']
# ['sunrise', '日の出']
# ['sunset', '日没']
# ['superior', '上位の']
# ['supply', '供給する']
# ['surety', '保証']
# ['surface', '表面']
# ['surprise', '驚かす・驚き']
# ['surround', '取り囲む']
# ['survey', '見渡す']
# ['survive', '生き残る']
# ['suspect', '～ではないかと思う']
# ['sway', '揺らす・左右する']
# ['swear', '誓う・宣誓する']
# ['swing', '揺れ動く・揺り動かす']
# ['symbolic', '象徴的な・記号の']
# ['symbol', '象徴・記号']
# ['sympathy', '同情']
# ['tactics', '戦術']
# ['talent', '才能・才能のある人・タレント']
# ['taste', '味覚・味わう']
# ['tax', '税']
# ['temperature', '温度']
# ['temper', '気質']
# ['temporary', '一時の']
# ['tend', '～する傾向がある']
# ['tense', '張り詰めた・緊張する・時制']
# ['term', '期間']
# ['terrestrial', '地球の']
# ['terrible', 'ひどい・恐ろしい']
# ['terrific', '素晴らしい・すごい']
# ['territory', '領土・領域・縄張り']
# ['textbook', '教科書']
# ['texture', '質感・構造']
# ['theater', '劇場']
# ['thermometer', '温度計']
# ['thickness', '厚さ']
# ['thick', '厚い・濃い']
# ['thin', '薄い']
# ['thirsty', 'のどが渇いた']
# ['thought', '思考']
# ['thousand', '1000・千']
# ['thread', '糸・糸を通す']
# ['throne', '玉座']
# ['tide', '潮']
# ['tidy', 'きれい好きな・きちんとした']
# ['tile', 'タイル・瓦・タイルを張る']
# ['tiny', 'ごく小さな']
# ['tire', '疲れさせる']
# ['toddler', 'よちよち歩きの幼児']
# ['token', 'しるし・証拠']
# ['tolerance', '寛容']
# ['tolerant', '寛容な・耐性のある']
# ['tool', '道具']
# ['top', '頂上・一番上の']
# ['tour', '旅行・旅行する']
# ['trace', '痕跡・跡を辿る']
# ['track', '通り道・追跡する']
# ['trade', '取引・取引する']
# ['tradition', '伝統']
# ['traffic', '交通']
# ['tragedy', '悲劇']
# ['training', '訓練']
# ['transparent', '透明な']
# ['transportation', '輸送']
# ['transport', '輸送する']
# ['travel', '旅行する・旅行']
# ['treasure', '財宝']
# ['treatment', '取り扱い・待遇・治療']
# ['treaty', '条約']
# ['treat', '取り扱う']
# ['tremble', '震える']
# ['trend', '傾向']
# ['triangle', '三角形']
# ['triangular', '三角の']
# ['trip', '旅行']
# ['triumph', '勝利、勝利する']
# ['trivial', '些細な']
# ['trust', '信頼']
# ['twilight', 'たそがれ']
# ['twinkle', 'きらきら光る・(星などの)きらめき']
# ['tyrant', '暴君']
# ['ugly', '醜い']
# ['underground', '地下鉄・地下道・地下の・地下で']
# ['unforgivable', '許されない']
# ['ungulate', '有蹄動物']
# ['unite', '団結する']
# ['universe', '宇宙']
# ['urban', '都市の・都会の']
# ['urge', '駆り立てる・衝動']
# ['urine', '尿']
# ['usage', '使用法・慣習']
# ['usual', 'いつもの']
# ['utmost', '最大(限度)の']
# ['utter', '全くの・声を発する']
# ['vacant', '空いている']
# ['vain', '自惚れの強い・無駄な']
# ['validate', '有効にする・正当性を立証する']
# ['validation', '検証・確認・認証']
# ['valid', '確かな・正当な・有効な']
# ['value', '価値・評価する']
# ['vary', '変える']
# ['vegetable', '野菜・植物']
# ['vehicle', '車両']
# ['velocity', '速さ・速度']
# ['verdict', '評決']
# ['verify', '証明する・確認する']
# ['versatile', '多才な・多用途の']
# ['vertical', '垂直な']
# ['vibrate', '揺れる・震動する']
# ['victory', '勝利']
# ['view', '見ること']
# ['vigor', '精力・活力']
# ['virtue', '美徳']
# ['visible', '目に見える']
# ['visitor', '訪問者']
# ['visual', '視覚の']
# ['vitality', '生命力・活力']
# ['vital', '生命の']
# ['voyage', '旅・航海']
# ['vulgar', '下品な']
# ['vulnerable', '脆弱な・傷つきやすい']
# ['wage', '賃金']
# ['wagon', '荷馬車']
# ['wallet', '財布・札入れ']
# ['warranty', '保証・認可']
# ['warrant', '正当な根拠・正当化する']
# ['waste', '浪費する']
# ['waver', '揺らめく']
# ['wave', '波・(波の様に)揺れる・手を振る']
# ['wax', '蝋・ワックス・(月が)満ちる']
# ['wealth', '富・財産']
# ['weapon', '武器']
# ['weather', '天気']
# ['weekly', '毎週の・週一回の']
# ['weight', '重さ']
# ['welfare', '福祉']
# ['wheel', '車輪']
# ['whisper', 'ささやく']
# ['width', '幅']
# ['wild', '野生の']
# ['willing', '～するのをいとわない']
# ['wince', 'ひるむ・たじろぐ']
# ['win', '勝利を得る・勝ち取る']
# ['wisdom', '知恵']
# ['workshop', '作業場']
# ['worry', '心配させる']
# ['worship', '崇拝する']
# ['worthy', '価値ある']
# ['worth', '～の価値がある']
# ['wound', '傷つける']
# ['wrap', '包む・包むもの']
# ['wrath', '激怒']
# ['yearly', '毎年の・年一回の']
# ['youth', '若さ・若者']
# ['treatment', '取り扱い・待遇・治療']
# ['exceptional', '例外的な・並外れた']
# ['exception', '例外・除外・異議']
# ['except', '～を除いて・～でなければ']
# ['token', 'しるし・証拠']
# ['gesture', '身ぶり・身ぶりで示す']
# ['symbolic', '象徴的な・記号の']
# ['symbol', '象徴・記号']
# ['hierarchy', '階層・階層制度']
# ['status', '地位・身分・状態']

# %%
#韓国語

import requests
from bs4 import BeautifulSoup
import json

URL = "https://coneru-web.com/hangeul-words/"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

hangul = soup.find_all("td", class_="hangeul-link_td03")
nihongo = soup.find_all("td", class_="hangeul-link_td01")

nihongo = [i for i in nihongo if "一覧" not in i.text]

# ペアを辞書として保存するためのリストを作成
word_pairs = []

for i, k in zip(hangul, nihongo):
    hangul_word = i.text
    nihongo_word = k.text

    # 各ペアのための辞書を作成
    word_pair_dict = {"hangul": hangul_word, "nihongo": nihongo_word}

    # 辞書をリストに追加
    word_pairs.append(word_pair_dict)

# 辞書のリストをJSON形式に変換
json_data = json.dumps(word_pairs, ensure_ascii=False, indent=2)

# JSONデータを表示
print(json_data)

# %%
#国民の祝日

URL = "https://www8.cao.go.jp/chosei/shukujitsu/gaiyou.html"
r = requests.get(URL)
soup = BeautifulSoup(r.content, "html.parser")

data = soup.find_all("table")[1].find("tbody").find_all("tr")
meisyo = [i.find("th").text for i in data if "休日" not in i.text]
date = [i.find("td").text for i in data if "休日" not in i.text]

# ペアを辞書として保存するためのリストを作成
word_pairs = []

for meisyo_word, date_word in zip(meisyo, date):


    # 各ペアのための辞書を作成
    word_pair_dict = {"meisyo": meisyo_word, "date": date_word}

    # 辞書をリストに追加
    word_pairs.append(word_pair_dict)

# 辞書のリストをJSON形式に変換
json_data = json.dumps(word_pairs, ensure_ascii=False, indent=2)

# JSONデータを表示
print(json_data)
# Out:
# [
#   {
#     "meisyo": "元日",
#     "date": "1月1日"
#   },
#   {
#     "meisyo": "成人の日",
#     "date": "1月8日"
#   },
#   {
#     "meisyo": "建国記念の日",
#     "date": "2月11日"
#   },
#   {
#     "meisyo": "天皇誕生日",
#     "date": "2月23日"
#   },
#   {
#     "meisyo": "春分の日",
#     "date": "3月20日"
#   },
#   {
#     "meisyo": "昭和の日",
#     "date": "4月29日"
#   },
#   {
#     "meisyo": "憲法記念日",
#     "date": "5月3日"
#   },
#   {
#     "meisyo": "みどりの日",
#     "date": "5月4日"
#   },
#   {
#     "meisyo": "こどもの日",
#     "date": "5月5日"
#   },
#   {
#     "meisyo": "海の日",
#     "date": "7月15日"
#   },
#   {
#     "meisyo": "山の日",
#     "date": "8月11日"
#   },
#   {
#     "meisyo": "敬老の日",
#     "date": "9月16日"
#   },
#   {
#     "meisyo": "秋分の日",
#     "date": "9月22日"
#   },
#   {
#     "meisyo": "スポーツの日",
#     "date": "10月14日"
#   },
#   {
#     "meisyo": "文化の日",
#     "date": "11月3日"
#   },
#   {
#     "meisyo": "勤労感謝の日",
#     "date": "11月23日"
#   }
# ]
